# %% [markdown]
# <a href="https://colab.research.google.com/github/mlvssyaswanth/3D-Background/blob/main/OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch torchvision torchaudio pillow opencv-python-headless
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
from PIL import Image
import zipfile
import glob
import shutil

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_folder = "/content/drive/MyDrive/OCR_Dataset"  # Update this path
extract_path = "/content/extracted_OCR_Dataset/"  # Temporary extraction folder
output_text_file = "/content/ocr_results.txt"

# %%
os.makedirs(extract_path, exist_ok=True)

zip_files = [f for f in os.listdir(dataset_folder) if f.endswith(".zip")]

for zip_file in zip_files:
    zip_path = os.path.join(dataset_folder, zip_file)
    print(f" Extracting: {zip_file}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(f" All ZIP files extracted to: {extract_path}")
# Out:
#  Extracting: Components-Real.zip...
#  Extracting: Date-Real.zip...
#  Extracting: Date-Synth.zip...
#  Extracting: Products-Real.zip...
#  All ZIP files extracted to: /content/extracted_OCR_Dataset/

# %%
# Find All Images (Including Subfolders)
image_files = glob.glob(os.path.join(extract_path, "**", "*.[jp][pn]g"), recursive=True)

print(f"Found {len(image_files)} images in dataset.")
print(" Example image paths:", image_files[:5])

if not image_files:
    raise RuntimeError(" No images found! Check dataset structure.")
# Out:
# Found 131769 images in dataset.
#  Example image paths: ['/content/extracted_OCR_Dataset/Date-Synth/images/55156.jpg', '/content/extracted_OCR_Dataset/Date-Synth/images/62308.jpg', '/content/extracted_OCR_Dataset/Date-Synth/images/92161.jpg', '/content/extracted_OCR_Dataset/Date-Synth/images/110046.jpg', '/content/extracted_OCR_Dataset/Date-Synth/images/60880.jpg']

# %%
# Preprocess Images for OCR
def preprocess_image(image_path):
    try:
        image = cv2.imread(image_path)
        if image is None:
            print(f" Could not read image: {image_path}")
            return None

        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)
        processed = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                          cv2.THRESH_BINARY, 11, 2)

        # Resize for better OCR accuracy
        processed = cv2.resize(processed, (1024, 1024), interpolation=cv2.INTER_CUBIC)

        return processed
    except Exception as e:
        print(f" Error processing {image_path}: {e}")
        return None

# %%
#  Load TrOCR Model
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-printed")
model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-printed").to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/224 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.50, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.13k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Config of the encoder: <class 'transformers.models.vit.modeling_vit.ViTModel'> is overwritten by shared encoder config: ViTConfig {
#   "attention_probs_dropout_prob": 0.0,
#   "encoder_stride": 16,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 768,
#   "image_size": 384,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "model_type": "vit",
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "patch_size": 16,
#   "pooler_act": "tanh",
#   "pooler_output_size": 768,
#   "qkv_bias": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.50.0"
# }
#
# Config of the decoder: <class 'transformers.models.trocr.modeling_trocr.TrOCRForCausalLM'> is overwritten by shared decoder config: TrOCRConfig {
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_cross_attention": true,
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.0,
#   "cross_attention_hidden_size": 768,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "eos_token_id": 2,
#   "init_std": 0.02,
#   "is_decoder": true,
#   "layernorm_embedding": true,
#   "max_position_embeddings": 512,
#   "model_type": "trocr",
#   "pad_token_id": 1,
#   "scale_embedding": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.50.0",
#   "use_cache": false,
#   "use_learned_position_embeddings": true,
#   "vocab_size": 50265
# }
#
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-base-printed and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# generation_config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Perform OCR with TrOCR for First 10,000 Images
ocr_results = {}

#  Limit processing to 10,000 images
max_images = min(10000, len(image_files))

for i, img_path in enumerate(image_files[:max_images]):  # Process first 10,000 images
    print(f"🔍 Processing {i+1}/{max_images}: {img_path}")

    # Preprocess the image
    processed_img = preprocess_image(img_path)
    if processed_img is None:
        continue

    # Convert OpenCV image to PIL format
    pil_image = Image.fromarray(processed_img).convert("RGB")

    #  Prepare image for TrOCR
    pixel_values = processor(pil_image, return_tensors="pt").pixel_values.to(device)

    #  Perform OCR
    with torch.no_grad():
        generated_ids = model.generate(pixel_values)
        extracted_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

    print(f"📄 Extracted Text:\n{extracted_text}")

    #  Store result
    ocr_results[img_path] = extracted_text

print(f" Finished processing {max_images} images.")
# Out:
# Streaming output truncated to the last 5000 lines.
# 11/2012
# 🔍 Processing 8335/10000: /content/extracted_OCR_Dataset/Date-Synth/images/97424.jpg
# 📄 Extracted Text:
# 09/2018
# 🔍 Processing 8336/10000: /content/extracted_OCR_Dataset/Date-Synth/images/92048.jpg
# 📄 Extracted Text:
# 12-09-2026
# 🔍 Processing 8337/10000: /content/extracted_OCR_Dataset/Date-Synth/images/37136.jpg
# 📄 Extracted Text:
# 2029 01
# 🔍 Processing 8338/10000: /content/extracted_OCR_Dataset/Date-Synth/images/94748.jpg
# 📄 Extracted Text:
# POPA QUID 22
# 🔍 Processing 8339/10000: /content/extracted_OCR_Dataset/Date-Synth/images/24667.jpg
# 📄 Extracted Text:
# 2206.2015
# 🔍 Processing 8340/10000: /content/extracted_OCR_Dataset/Date-Synth/images/122738.jpg
# 📄 Extracted Text:
# 31/N6V/17@
# 🔍 Processing 8341/10000: /content/extracted_OCR_Dataset/Date-Synth/images/20530.jpg
# 📄 Extracted Text:
# AUG/29/16
# 🔍 Processing 8342/10000: /content/extracted_OCR_Dataset/Date-Synth/images/113808.jpg
# 📄 Extracted Text:
# 07.APR.25:
# 🔍 Processing 8343/10000: /content/extracted_OCR_Dataset/Date-Synth/images/108210.jpg
# 📄 Extracted Text:
# 2028/NOV/03/(
# 🔍 Processing 8344/10000: /content/extracted_OCR_Dataset/Date-Synth/images/87593.jpg
# 📄 Extracted Text:
# NOV/2016
# 🔍 Processing 8345/10000: /content/extracted_OCR_Dataset/Date-Synth/images/119403.jpg
# 📄 Extracted Text:
# 07-2020%
# 🔍 Processing 8346/10000: /content/extracted_OCR_Dataset/Date-Synth/images/63699.jpg
# 📄 Extracted Text:
# (2)02-2015
# 🔍 Processing 8347/10000: /content/extracted_OCR_Dataset/Date-Synth/images/92642.jpg
# 📄 Extracted Text:
# 02-05 2018
# 🔍 Processing 8348/10000: /content/extracted_OCR_Dataset/Date-Synth/images/32439.jpg
# 📄 Extracted Text:
# ITEMGR:20215
# 🔍 Processing 8349/10000: /content/extracted_OCR_Dataset/Date-Synth/images/46963.jpg
# 📄 Extracted Text:
# 08/02
# 🔍 Processing 8350/10000: /content/extracted_OCR_Dataset/Date-Synth/images/43660.jpg
# 📄 Extracted Text:
# SO MAY 28
# 🔍 Processing 8351/10000: /content/extracted_OCR_Dataset/Date-Synth/images/74602.jpg
# 📄 Extracted Text:
# OFF
# 🔍 Processing 8352/10000: /content/extracted_OCR_Dataset/Date-Synth/images/32479.jpg
# 📄 Extracted Text:
# G: OCT 2018
# 🔍 Processing 8353/10000: /content/extracted_OCR_Dataset/Date-Synth/images/111668.jpg
# 📄 Extracted Text:
# FEB 2026^
# 🔍 Processing 8354/10000: /content/extracted_OCR_Dataset/Date-Synth/images/115435.jpg
# 📄 Extracted Text:
# (13.12.2013
# 🔍 Processing 8355/10000: /content/extracted_OCR_Dataset/Date-Synth/images/116795.jpg
# 📄 Extracted Text:
# 2018-08-08%
# 🔍 Processing 8356/10000: /content/extracted_OCR_Dataset/Date-Synth/images/33454.jpg
# 📄 Extracted Text:
# 09 SEP 2018
# 🔍 Processing 8357/10000: /content/extracted_OCR_Dataset/Date-Synth/images/46579.jpg
# 📄 Extracted Text:
# @9.00
# 🔍 Processing 8358/10000: /content/extracted_OCR_Dataset/Date-Synth/images/82188.jpg
# 📄 Extracted Text:
# 2028 AUG 09
# 🔍 Processing 8359/10000: /content/extracted_OCR_Dataset/Date-Synth/images/83413.jpg
# 📄 Extracted Text:
# S/P/ 21/20:13
# 🔍 Processing 8360/10000: /content/extracted_OCR_Dataset/Date-Synth/images/55669.jpg
# 📄 Extracted Text:
# MAR2028
# 🔍 Processing 8361/10000: /content/extracted_OCR_Dataset/Date-Synth/images/83195.jpg
# 📄 Extracted Text:
# DEC/08/2023
# 🔍 Processing 8362/10000: /content/extracted_OCR_Dataset/Date-Synth/images/103386.jpg
# 📄 Extracted Text:
# 05/03
# 🔍 Processing 8363/10000: /content/extracted_OCR_Dataset/Date-Synth/images/29193.jpg
# 📄 Extracted Text:
# 2025/NO-UT/10
# 🔍 Processing 8364/10000: /content/extracted_OCR_Dataset/Date-Synth/images/94589.jpg
# 📄 Extracted Text:
# 20-JUN-12
# 🔍 Processing 8365/10000: /content/extracted_OCR_Dataset/Date-Synth/images/14966.jpg
# 📄 Extracted Text:
# MAY.2016
# 🔍 Processing 8366/10000: /content/extracted_OCR_Dataset/Date-Synth/images/47270.jpg
# 📄 Extracted Text:
# 10-25
# 🔍 Processing 8367/10000: /content/extracted_OCR_Dataset/Date-Synth/images/80887.jpg
# 📄 Extracted Text:
# 09-03-2022
# 🔍 Processing 8368/10000: /content/extracted_OCR_Dataset/Date-Synth/images/31529.jpg
# 📄 Extracted Text:
# NOV: 03/2017
# 🔍 Processing 8369/10000: /content/extracted_OCR_Dataset/Date-Synth/images/15806.jpg
# 📄 Extracted Text:
# OCT 2016
# 🔍 Processing 8370/10000: /content/extracted_OCR_Dataset/Date-Synth/images/43837.jpg
# 📄 Extracted Text:
# 19 JUN 20
# 🔍 Processing 8371/10000: /content/extracted_OCR_Dataset/Date-Synth/images/08953.jpg
# 📄 Extracted Text:
# 16/0CT/2016
# 🔍 Processing 8372/10000: /content/extracted_OCR_Dataset/Date-Synth/images/41437.jpg
# 📄 Extracted Text:
# 180408
# 🔍 Processing 8373/10000: /content/extracted_OCR_Dataset/Date-Synth/images/91184.jpg
# 📄 Extracted Text:
# 0113
# 🔍 Processing 8374/10000: /content/extracted_OCR_Dataset/Date-Synth/images/60649.jpg
# 📄 Extracted Text:
# 20 24,MAY:17
# 🔍 Processing 8375/10000: /content/extracted_OCR_Dataset/Date-Synth/images/19659.jpg
# 📄 Extracted Text:
# 25 SEP 18
# 🔍 Processing 8376/10000: /content/extracted_OCR_Dataset/Date-Synth/images/17816.jpg
# 📄 Extracted Text:
# 17-09-20
# 🔍 Processing 8377/10000: /content/extracted_OCR_Dataset/Date-Synth/images/113127.jpg
# 📄 Extracted Text:
# (11.06.18
# 🔍 Processing 8378/10000: /content/extracted_OCR_Dataset/Date-Synth/images/124064.jpg
# 📄 Extracted Text:
# .02/07
# 🔍 Processing 8379/10000: /content/extracted_OCR_Dataset/Date-Synth/images/85702.jpg
# 📄 Extracted Text:
# *09-2015
# 🔍 Processing 8380/10000: /content/extracted_OCR_Dataset/Date-Synth/images/68500.jpg
# 📄 Extracted Text:
# 3.0 ZN
# 🔍 Processing 8381/10000: /content/extracted_OCR_Dataset/Date-Synth/images/33237.jpg
# 📄 Extracted Text:
# 20-FEB-2020
# 🔍 Processing 8382/10000: /content/extracted_OCR_Dataset/Date-Synth/images/92354.jpg
# 📄 Extracted Text:
# -27-12 2027
# 🔍 Processing 8383/10000: /content/extracted_OCR_Dataset/Date-Synth/images/116865.jpg
# 📄 Extracted Text:
# 2013.06.22A
# 🔍 Processing 8384/10000: /content/extracted_OCR_Dataset/Date-Synth/images/06121.jpg
# 📄 Extracted Text:
# M A Y@2 7.2 0 1 6
# 🔍 Processing 8385/10000: /content/extracted_OCR_Dataset/Date-Synth/images/33128.jpg
# 📄 Extracted Text:
# 20/JAN/2017
# 🔍 Processing 8386/10000: /content/extracted_OCR_Dataset/Date-Synth/images/27923.jpg
# 📄 Extracted Text:
# 2026-01-07
# 🔍 Processing 8387/10000: /content/extracted_OCR_Dataset/Date-Synth/images/122787.jpg
# 📄 Extracted Text:
# (4 DAY.25)
# 🔍 Processing 8388/10000: /content/extracted_OCR_Dataset/Date-Synth/images/123440.jpg
# 📄 Extracted Text:
# CHANGE
# 🔍 Processing 8389/10000: /content/extracted_OCR_Dataset/Date-Synth/images/63917.jpg
# 📄 Extracted Text:
# 2621/06/04
# 🔍 Processing 8390/10000: /content/extracted_OCR_Dataset/Date-Synth/images/89539.jpg
# 📄 Extracted Text:
# 02/APR/28
# 🔍 Processing 8391/10000: /content/extracted_OCR_Dataset/Date-Synth/images/90394.jpg
# 📄 Extracted Text:
# MAR.13.19
# 🔍 Processing 8392/10000: /content/extracted_OCR_Dataset/Date-Synth/images/61654.jpg
# 📄 Extracted Text:
# 20 24 08.24
# 🔍 Processing 8393/10000: /content/extracted_OCR_Dataset/Date-Synth/images/82465.jpg
# 📄 Extracted Text:
# # 2018,MAY.28
# 🔍 Processing 8394/10000: /content/extracted_OCR_Dataset/Date-Synth/images/28121.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 8395/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84692.jpg
# 📄 Extracted Text:
# 28/FEB/2027
# 🔍 Processing 8396/10000: /content/extracted_OCR_Dataset/Date-Synth/images/25617.jpg
# 📄 Extracted Text:
# 23 05 2021
# 🔍 Processing 8397/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84398.jpg
# 📄 Extracted Text:
# 07-SEP-2017
# 🔍 Processing 8398/10000: /content/extracted_OCR_Dataset/Date-Synth/images/24565.jpg
# 📄 Extracted Text:
# 05-06 2029
# 🔍 Processing 8399/10000: /content/extracted_OCR_Dataset/Date-Synth/images/40047.jpg
# 📄 Extracted Text:
# DEHOHOR
# 🔍 Processing 8400/10000: /content/extracted_OCR_Dataset/Date-Synth/images/113278.jpg
# 📄 Extracted Text:
# 25.NOV.24 :
# 🔍 Processing 8401/10000: /content/extracted_OCR_Dataset/Date-Synth/images/04702.jpg
# 📄 Extracted Text:
# 2028.JAN.30
# 🔍 Processing 8402/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84428.jpg
# 📄 Extracted Text:
# 06.NOV.2022
# 🔍 Processing 8403/10000: /content/extracted_OCR_Dataset/Date-Synth/images/50484.jpg
# 📄 Extracted Text:
# 2015AUG14
# 🔍 Processing 8404/10000: /content/extracted_OCR_Dataset/Date-Synth/images/87128.jpg
# 📄 Extracted Text:
# AUG 2015
# 🔍 Processing 8405/10000: /content/extracted_OCR_Dataset/Date-Synth/images/12661.jpg
# 📄 Extracted Text:
# 2027-03
# 🔍 Processing 8406/10000: /content/extracted_OCR_Dataset/Date-Synth/images/19947.jpg
# 📄 Extracted Text:
# 27 JAN 16
# 🔍 Processing 8407/10000: /content/extracted_OCR_Dataset/Date-Synth/images/41155.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 8408/10000: /content/extracted_OCR_Dataset/Date-Synth/images/55437.jpg
# 📄 Extracted Text:
# JAN2029
# 🔍 Processing 8409/10000: /content/extracted_OCR_Dataset/Date-Synth/images/115317.jpg
# 📄 Extracted Text:
# 11:21
# 🔍 Processing 8410/10000: /content/extracted_OCR_Dataset/Date-Synth/images/55853.jpg
# 📄 Extracted Text:
# 13DEC16
# 🔍 Processing 8411/10000: /content/extracted_OCR_Dataset/Date-Synth/images/124733.jpg
# 📄 Extracted Text:
# : 7:42:9%
# 🔍 Processing 8412/10000: /content/extracted_OCR_Dataset/Date-Synth/images/122473.jpg
# 📄 Extracted Text:
# GSTAL: MARY
# 🔍 Processing 8413/10000: /content/extracted_OCR_Dataset/Date-Synth/images/114488.jpg
# 📄 Extracted Text:
# MAR-12-23/
# 🔍 Processing 8414/10000: /content/extracted_OCR_Dataset/Date-Synth/images/52264.jpg
# 📄 Extracted Text:
# JUN102027
# 🔍 Processing 8415/10000: /content/extracted_OCR_Dataset/Date-Synth/images/102756.jpg
# 📄 Extracted Text:
# OFF:26:15
# 🔍 Processing 8416/10000: /content/extracted_OCR_Dataset/Date-Synth/images/69310.jpg
# 📄 Extracted Text:
# 209570
# 🔍 Processing 8417/10000: /content/extracted_OCR_Dataset/Date-Synth/images/59060.jpg
# 📄 Extracted Text:
# 2014 11 01
# 🔍 Processing 8418/10000: /content/extracted_OCR_Dataset/Date-Synth/images/49932.jpg
# 📄 Extracted Text:
# AUG2024
# 🔍 Processing 8419/10000: /content/extracted_OCR_Dataset/Date-Synth/images/80692.jpg
# 📄 Extracted Text:
# 28/04/2020)
# 🔍 Processing 8420/10000: /content/extracted_OCR_Dataset/Date-Synth/images/26794.jpg
# 📄 Extracted Text:
# 2022.00.00
# 🔍 Processing 8421/10000: /content/extracted_OCR_Dataset/Date-Synth/images/98277.jpg
# 📄 Extracted Text:
# 2017-02
# 🔍 Processing 8422/10000: /content/extracted_OCR_Dataset/Date-Synth/images/122021.jpg
# 📄 Extracted Text:
# A 10 08 18
# 🔍 Processing 8423/10000: /content/extracted_OCR_Dataset/Date-Synth/images/64722.jpg
# 📄 Extracted Text:
# 27 03 2013
# 🔍 Processing 8424/10000: /content/extracted_OCR_Dataset/Date-Synth/images/11848.jpg
# 📄 Extracted Text:
# 36-101
# 🔍 Processing 8425/10000: /content/extracted_OCR_Dataset/Date-Synth/images/52335.jpg
# 📄 Extracted Text:
# JAN2315
# 🔍 Processing 8426/10000: /content/extracted_OCR_Dataset/Date-Synth/images/37604.jpg
# 📄 Extracted Text:
# 2024/01
# 🔍 Processing 8427/10000: /content/extracted_OCR_Dataset/Date-Synth/images/49689.jpg
# 📄 Extracted Text:
# OCT2018
# 🔍 Processing 8428/10000: /content/extracted_OCR_Dataset/Date-Synth/images/101613.jpg
# 📄 Extracted Text:
# 02/NOV/19
# 🔍 Processing 8429/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84990.jpg
# 📄 Extracted Text:
# 24 NOV 2016
# 🔍 Processing 8430/10000: /content/extracted_OCR_Dataset/Date-Synth/images/66357.jpg
# 📄 Extracted Text:
# 20130478
# 🔍 Processing 8431/10000: /content/extracted_OCR_Dataset/Date-Synth/images/29714.jpg
# 📄 Extracted Text:
# 2019JAN.13
# 🔍 Processing 8432/10000: /content/extracted_OCR_Dataset/Date-Synth/images/68264.jpg
# 📄 Extracted Text:
# I001 2018
# 🔍 Processing 8433/10000: /content/extracted_OCR_Dataset/Date-Synth/images/82486.jpg
# 📄 Extracted Text:
# 2013/JUN25
# 🔍 Processing 8434/10000: /content/extracted_OCR_Dataset/Date-Synth/images/58709.jpg
# 📄 Extracted Text:
# 20 22 0112
# 🔍 Processing 8435/10000: /content/extracted_OCR_Dataset/Date-Synth/images/68035.jpg
# 📄 Extracted Text:
# 29/04/2028
# 🔍 Processing 8436/10000: /content/extracted_OCR_Dataset/Date-Synth/images/41718.jpg
# 📄 Extracted Text:
# 12.08 17
# 🔍 Processing 8437/10000: /content/extracted_OCR_Dataset/Date-Synth/images/58305.jpg
# 📄 Extracted Text:
# 2014702
# 🔍 Processing 8438/10000: /content/extracted_OCR_Dataset/Date-Synth/images/92913.jpg
# 📄 Extracted Text:
# TOTAL :
# 🔍 Processing 8439/10000: /content/extracted_OCR_Dataset/Date-Synth/images/100712.jpg
# 📄 Extracted Text:
# 24:02-17
# 🔍 Processing 8440/10000: /content/extracted_OCR_Dataset/Date-Synth/images/04482.jpg
# 📄 Extracted Text:
# 2025 FEB 04
# 🔍 Processing 8441/10000: /content/extracted_OCR_Dataset/Date-Synth/images/19385.jpg
# 📄 Extracted Text:
# 27.AUG.15
# 🔍 Processing 8442/10000: /content/extracted_OCR_Dataset/Date-Synth/images/91320.jpg
# 📄 Extracted Text:
# 08:26
# 🔍 Processing 8443/10000: /content/extracted_OCR_Dataset/Date-Synth/images/37063.jpg
# 📄 Extracted Text:
# 2012 04
# 🔍 Processing 8444/10000: /content/extracted_OCR_Dataset/Date-Synth/images/75901.jpg
# 📄 Extracted Text:
# 2015/07/03
# 🔍 Processing 8445/10000: /content/extracted_OCR_Dataset/Date-Synth/images/50588.jpg
# 📄 Extracted Text:
# MAR215
# 🔍 Processing 8446/10000: /content/extracted_OCR_Dataset/Date-Synth/images/92704.jpg
# 📄 Extracted Text:
# 02:08:2029
# 🔍 Processing 8447/10000: /content/extracted_OCR_Dataset/Date-Synth/images/32206.jpg
# 📄 Extracted Text:
# 04F6/205
# 🔍 Processing 8448/10000: /content/extracted_OCR_Dataset/Date-Synth/images/12334.jpg
# 📄 Extracted Text:
# 2027/12
# 🔍 Processing 8449/10000: /content/extracted_OCR_Dataset/Date-Synth/images/34952.jpg
# 📄 Extracted Text:
# 06-2018
# 🔍 Processing 8450/10000: /content/extracted_OCR_Dataset/Date-Synth/images/16695.jpg
# 📄 Extracted Text:
# 08:08:14
# 🔍 Processing 8451/10000: /content/extracted_OCR_Dataset/Date-Synth/images/04302.jpg
# 📄 Extracted Text:
# 2022 NOV(19
# 🔍 Processing 8452/10000: /content/extracted_OCR_Dataset/Date-Synth/images/30247.jpg
# 📄 Extracted Text:
# NETTER:
# 🔍 Processing 8453/10000: /content/extracted_OCR_Dataset/Date-Synth/images/115645.jpg
# 📄 Extracted Text:
# : 25:02 2022
# 🔍 Processing 8454/10000: /content/extracted_OCR_Dataset/Date-Synth/images/36797.jpg
# 📄 Extracted Text:
# :2028/11
# 🔍 Processing 8455/10000: /content/extracted_OCR_Dataset/Date-Synth/images/124362.jpg
# 📄 Extracted Text:
# : 09:31
# 🔍 Processing 8456/10000: /content/extracted_OCR_Dataset/Date-Synth/images/27242.jpg
# 📄 Extracted Text:
# 2012-02-05
# 🔍 Processing 8457/10000: /content/extracted_OCR_Dataset/Date-Synth/images/111918.jpg
# 📄 Extracted Text:
# : FEB/2015
# 🔍 Processing 8458/10000: /content/extracted_OCR_Dataset/Date-Synth/images/119723.jpg
# 📄 Extracted Text:
# (RM)
# 🔍 Processing 8459/10000: /content/extracted_OCR_Dataset/Date-Synth/images/40710.jpg
# 📄 Extracted Text:
# 17/04/08
# 🔍 Processing 8460/10000: /content/extracted_OCR_Dataset/Date-Synth/images/102905.jpg
# 📄 Extracted Text:
# J00714/28-
# 🔍 Processing 8461/10000: /content/extracted_OCR_Dataset/Date-Synth/images/40003.jpg
# 📄 Extracted Text:
# 2 6 - 0 6 : 2 6
# 🔍 Processing 8462/10000: /content/extracted_OCR_Dataset/Date-Synth/images/26430.jpg
# 📄 Extracted Text:
# 2012.05.06
# 🔍 Processing 8463/10000: /content/extracted_OCR_Dataset/Date-Synth/images/14647.jpg
# 📄 Extracted Text:
# O.C.T / 2 0'1 3
# 🔍 Processing 8464/10000: /content/extracted_OCR_Dataset/Date-Synth/images/20396.jpg
# 📄 Extracted Text:
# NOV/08/15
# 🔍 Processing 8465/10000: /content/extracted_OCR_Dataset/Date-Synth/images/13195.jpg
# 📄 Extracted Text:
# 2026-04
# 🔍 Processing 8466/10000: /content/extracted_OCR_Dataset/Date-Synth/images/05587.jpg
# 📄 Extracted Text:
# 2019-001-03
# 🔍 Processing 8467/10000: /content/extracted_OCR_Dataset/Date-Synth/images/103744.jpg
# 📄 Extracted Text:
# :03.06
# 🔍 Processing 8468/10000: /content/extracted_OCR_Dataset/Date-Synth/images/70154.jpg
# 📄 Extracted Text:
# 31052013
# 🔍 Processing 8469/10000: /content/extracted_OCR_Dataset/Date-Synth/images/60128.jpg
# 📄 Extracted Text:
# 28-23-JUNAH08
# 🔍 Processing 8470/10000: /content/extracted_OCR_Dataset/Date-Synth/images/37956.jpg
# 📄 Extracted Text:
# 2024/01
# 🔍 Processing 8471/10000: /content/extracted_OCR_Dataset/Date-Synth/images/96712.jpg
# 📄 Extracted Text:
# 28.MAY,2029
# 🔍 Processing 8472/10000: /content/extracted_OCR_Dataset/Date-Synth/images/48479.jpg
# 📄 Extracted Text:
# 24JUN21
# 🔍 Processing 8473/10000: /content/extracted_OCR_Dataset/Date-Synth/images/35744.jpg
# 📄 Extracted Text:
# 0652020
# 🔍 Processing 8474/10000: /content/extracted_OCR_Dataset/Date-Synth/images/104353.jpg
# 📄 Extracted Text:
# DEC2.2012
# 🔍 Processing 8475/10000: /content/extracted_OCR_Dataset/Date-Synth/images/46664.jpg
# 📄 Extracted Text:
# 02-16
# 🔍 Processing 8476/10000: /content/extracted_OCR_Dataset/Date-Synth/images/42049.jpg
# 📄 Extracted Text:
# 2P- (RM)
# 🔍 Processing 8477/10000: /content/extracted_OCR_Dataset/Date-Synth/images/83679.jpg
# 📄 Extracted Text:
# OCT/14/2027
# 🔍 Processing 8478/10000: /content/extracted_OCR_Dataset/Date-Synth/images/89855.jpg
# 📄 Extracted Text:
# 29/SEP/27
# 🔍 Processing 8479/10000: /content/extracted_OCR_Dataset/Date-Synth/images/47358.jpg
# 📄 Extracted Text:
# 07/18
# 🔍 Processing 8480/10000: /content/extracted_OCR_Dataset/Date-Synth/images/37812.jpg
# 📄 Extracted Text:
# CASHIER
# 🔍 Processing 8481/10000: /content/extracted_OCR_Dataset/Date-Synth/images/12162.jpg
# 📄 Extracted Text:
# 2020.06
# 🔍 Processing 8482/10000: /content/extracted_OCR_Dataset/Date-Synth/images/07171.jpg
# 📄 Extracted Text:
# MAY:03 2017
# 🔍 Processing 8483/10000: /content/extracted_OCR_Dataset/Date-Synth/images/99130.jpg
# 📄 Extracted Text:
# MAY:2028
# 🔍 Processing 8484/10000: /content/extracted_OCR_Dataset/Date-Synth/images/106982.jpg
# 📄 Extracted Text:
# 24.01.2017
# 🔍 Processing 8485/10000: /content/extracted_OCR_Dataset/Date-Synth/images/113649.jpg
# 📄 Extracted Text:
# 29 DEC 29%
# 🔍 Processing 8486/10000: /content/extracted_OCR_Dataset/Date-Synth/images/82301.jpg
# 📄 Extracted Text:
# 2020-NOV-09
# 🔍 Processing 8487/10000: /content/extracted_OCR_Dataset/Date-Synth/images/113040.jpg
# 📄 Extracted Text:
# (19:11.06
# 🔍 Processing 8488/10000: /content/extracted_OCR_Dataset/Date-Synth/images/76081.jpg
# 📄 Extracted Text:
# 19/03/20201
# 🔍 Processing 8489/10000: /content/extracted_OCR_Dataset/Date-Synth/images/24121.jpg
# 📄 Extracted Text:
# (3/08/2029
# 🔍 Processing 8490/10000: /content/extracted_OCR_Dataset/Date-Synth/images/11057.jpg
# 📄 Extracted Text:
# 01, 20.25
# 🔍 Processing 8491/10000: /content/extracted_OCR_Dataset/Date-Synth/images/88964.jpg
# 📄 Extracted Text:
# SIR: 04F 09
# 🔍 Processing 8492/10000: /content/extracted_OCR_Dataset/Date-Synth/images/24016.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 8493/10000: /content/extracted_OCR_Dataset/Date-Synth/images/69247.jpg
# 📄 Extracted Text:
# 08/10/2028
# 🔍 Processing 8494/10000: /content/extracted_OCR_Dataset/Date-Synth/images/100702.jpg
# 📄 Extracted Text:
# 28:06:22
# 🔍 Processing 8495/10000: /content/extracted_OCR_Dataset/Date-Synth/images/102531.jpg
# 📄 Extracted Text:
# :JAN/19/25
# 🔍 Processing 8496/10000: /content/extracted_OCR_Dataset/Date-Synth/images/62965.jpg
# 📄 Extracted Text:
# TAINT TYPE
# 🔍 Processing 8497/10000: /content/extracted_OCR_Dataset/Date-Synth/images/92341.jpg
# 📄 Extracted Text:
# 29 - 03 - 2 0 1 5
# 🔍 Processing 8498/10000: /content/extracted_OCR_Dataset/Date-Synth/images/114458.jpg
# 📄 Extracted Text:
# . NOJ/03/23
# 🔍 Processing 8499/10000: /content/extracted_OCR_Dataset/Date-Synth/images/93128.jpg
# 📄 Extracted Text:
# ST @
# 🔍 Processing 8500/10000: /content/extracted_OCR_Dataset/Date-Synth/images/93442.jpg
# 📄 Extracted Text:
# (2026-02 03
# 🔍 Processing 8501/10000: /content/extracted_OCR_Dataset/Date-Synth/images/12455.jpg
# 📄 Extracted Text:
# 2020.03
# 🔍 Processing 8502/10000: /content/extracted_OCR_Dataset/Date-Synth/images/76881.jpg
# 📄 Extracted Text:
# 3L NOV-2023
# 🔍 Processing 8503/10000: /content/extracted_OCR_Dataset/Date-Synth/images/80947.jpg
# 📄 Extracted Text:
# 31.01.2024
# 🔍 Processing 8504/10000: /content/extracted_OCR_Dataset/Date-Synth/images/14202.jpg
# 📄 Extracted Text:
# JUL-2020
# 🔍 Processing 8505/10000: /content/extracted_OCR_Dataset/Date-Synth/images/99001.jpg
# 📄 Extracted Text:
# DEC/2018-
# 🔍 Processing 8506/10000: /content/extracted_OCR_Dataset/Date-Synth/images/126153.jpg
# 📄 Extracted Text:
# 11-2027
# 🔍 Processing 8507/10000: /content/extracted_OCR_Dataset/Date-Synth/images/80398.jpg
# 📄 Extracted Text:
# 27-03/2019
# 🔍 Processing 8508/10000: /content/extracted_OCR_Dataset/Date-Synth/images/97644.jpg
# 📄 Extracted Text:
# GST ST @ 6%
# 🔍 Processing 8509/10000: /content/extracted_OCR_Dataset/Date-Synth/images/110494.jpg
# 📄 Extracted Text:
# F 08/2023
# 🔍 Processing 8510/10000: /content/extracted_OCR_Dataset/Date-Synth/images/20267.jpg
# 📄 Extracted Text:
# SEP.23.18
# 🔍 Processing 8511/10000: /content/extracted_OCR_Dataset/Date-Synth/images/124681.jpg
# 📄 Extracted Text:
# 30.06/2012
# 🔍 Processing 8512/10000: /content/extracted_OCR_Dataset/Date-Synth/images/77802.jpg
# 📄 Extracted Text:
# 26/NOV/18
# 🔍 Processing 8513/10000: /content/extracted_OCR_Dataset/Date-Synth/images/73871.jpg
# 📄 Extracted Text:
# 2028.06:03
# 🔍 Processing 8514/10000: /content/extracted_OCR_Dataset/Date-Synth/images/20923.jpg
# 📄 Extracted Text:
# MAR-20-29
# 🔍 Processing 8515/10000: /content/extracted_OCR_Dataset/Date-Synth/images/99021.jpg
# 📄 Extracted Text:
# JAN-2022
# 🔍 Processing 8516/10000: /content/extracted_OCR_Dataset/Date-Synth/images/71253.jpg
# 📄 Extracted Text:
# 2025/11/22
# 🔍 Processing 8517/10000: /content/extracted_OCR_Dataset/Date-Synth/images/18120.jpg
# 📄 Extracted Text:
# 22-MAR-22
# 🔍 Processing 8518/10000: /content/extracted_OCR_Dataset/Date-Synth/images/118620.jpg
# 📄 Extracted Text:
# IT@5006@200096
# 🔍 Processing 8519/10000: /content/extracted_OCR_Dataset/Date-Synth/images/22145.jpg
# 📄 Extracted Text:
# 0.31/ 1 8
# 🔍 Processing 8520/10000: /content/extracted_OCR_Dataset/Date-Synth/images/18359.jpg
# 📄 Extracted Text:
# 12 JAN 24
# 🔍 Processing 8521/10000: /content/extracted_OCR_Dataset/Date-Synth/images/85708.jpg
# 📄 Extracted Text:
# 05/2017
# 🔍 Processing 8522/10000: /content/extracted_OCR_Dataset/Date-Synth/images/36905.jpg
# 📄 Extracted Text:
# 2019-04
# 🔍 Processing 8523/10000: /content/extracted_OCR_Dataset/Date-Synth/images/52520.jpg
# 📄 Extracted Text:
# NOV2019
# 🔍 Processing 8524/10000: /content/extracted_OCR_Dataset/Date-Synth/images/121409.jpg
# 📄 Extracted Text:
# + 22|01111
# 🔍 Processing 8525/10000: /content/extracted_OCR_Dataset/Date-Synth/images/21039.jpg
# 📄 Extracted Text:
# MAY:22:19
# 🔍 Processing 8526/10000: /content/extracted_OCR_Dataset/Date-Synth/images/25298.jpg
# 📄 Extracted Text:
# 14/07/2020
# 🔍 Processing 8527/10000: /content/extracted_OCR_Dataset/Date-Synth/images/86429.jpg
# 📄 Extracted Text:
# 2027 07
# 🔍 Processing 8528/10000: /content/extracted_OCR_Dataset/Date-Synth/images/62505.jpg
# 📄 Extracted Text:
# 2027 09 08
# 🔍 Processing 8529/10000: /content/extracted_OCR_Dataset/Date-Synth/images/127697.jpg
# 📄 Extracted Text:
# JAN/15/22
# 🔍 Processing 8530/10000: /content/extracted_OCR_Dataset/Date-Synth/images/66493.jpg
# 📄 Extracted Text:
# 2019/05/05
# 🔍 Processing 8531/10000: /content/extracted_OCR_Dataset/Date-Synth/images/81018.jpg
# 📄 Extracted Text:
# 2016 01 15
# 🔍 Processing 8532/10000: /content/extracted_OCR_Dataset/Date-Synth/images/87056.jpg
# 📄 Extracted Text:
# MAR/2015
# 🔍 Processing 8533/10000: /content/extracted_OCR_Dataset/Date-Synth/images/41547.jpg
# 📄 Extracted Text:
# 11.05 18
# 🔍 Processing 8534/10000: /content/extracted_OCR_Dataset/Date-Synth/images/109703.jpg
# 📄 Extracted Text:
# B 20/CCI/2020
# 🔍 Processing 8535/10000: /content/extracted_OCR_Dataset/Date-Synth/images/44545.jpg
# 📄 Extracted Text:
# JUL-31-15
# 🔍 Processing 8536/10000: /content/extracted_OCR_Dataset/Date-Synth/images/64168.jpg
# 📄 Extracted Text:
# (0805.2025
# 🔍 Processing 8537/10000: /content/extracted_OCR_Dataset/Date-Synth/images/111570.jpg
# 📄 Extracted Text:
# 2014/02/
# 🔍 Processing 8538/10000: /content/extracted_OCR_Dataset/Date-Synth/images/78507.jpg
# 📄 Extracted Text:
# OCT@118
# 🔍 Processing 8539/10000: /content/extracted_OCR_Dataset/Date-Synth/images/47564.jpg
# 📄 Extracted Text:
# 08/80
# 🔍 Processing 8540/10000: /content/extracted_OCR_Dataset/Date-Synth/images/03972.jpg
# 📄 Extracted Text:
# 2018.09.31
# 🔍 Processing 8541/10000: /content/extracted_OCR_Dataset/Date-Synth/images/75151.jpg
# 📄 Extracted Text:
# 07-AIL 2085
# 🔍 Processing 8542/10000: /content/extracted_OCR_Dataset/Date-Synth/images/58625.jpg
# 📄 Extracted Text:
# 2013/MAR/18
# 🔍 Processing 8543/10000: /content/extracted_OCR_Dataset/Date-Synth/images/124887.jpg
# 📄 Extracted Text:
# 2025-07-26
# 🔍 Processing 8544/10000: /content/extracted_OCR_Dataset/Date-Synth/images/78567.jpg
# 📄 Extracted Text:
# GIMAY2012
# 🔍 Processing 8545/10000: /content/extracted_OCR_Dataset/Date-Synth/images/35989.jpg
# 📄 Extracted Text:
# 01 2017
# 🔍 Processing 8546/10000: /content/extracted_OCR_Dataset/Date-Synth/images/50800.jpg
# 📄 Extracted Text:
# 25DEC2020.
# 🔍 Processing 8547/10000: /content/extracted_OCR_Dataset/Date-Synth/images/79108.jpg
# 📄 Extracted Text:
# 20520
# 🔍 Processing 8548/10000: /content/extracted_OCR_Dataset/Date-Synth/images/45376.jpg
# 📄 Extracted Text:
# AUE.09.15
# 🔍 Processing 8549/10000: /content/extracted_OCR_Dataset/Date-Synth/images/69924.jpg
# 📄 Extracted Text:
# 202911-03
# 🔍 Processing 8550/10000: /content/extracted_OCR_Dataset/Date-Synth/images/105566.jpg
# 📄 Extracted Text:
# FEB/26/2026/
# 🔍 Processing 8551/10000: /content/extracted_OCR_Dataset/Date-Synth/images/127836.jpg
# 📄 Extracted Text:
# @.30
# 🔍 Processing 8552/10000: /content/extracted_OCR_Dataset/Date-Synth/images/03207.jpg
# 📄 Extracted Text:
# 2 0.23- 1@17.2 0
# 🔍 Processing 8553/10000: /content/extracted_OCR_Dataset/Date-Synth/images/40308.jpg
# 📄 Extracted Text:
# 01-0102
# 🔍 Processing 8554/10000: /content/extracted_OCR_Dataset/Date-Synth/images/103806.jpg
# 📄 Extracted Text:
# 04.20
# 🔍 Processing 8555/10000: /content/extracted_OCR_Dataset/Date-Synth/images/19702.jpg
# 📄 Extracted Text:
# 20.NOV.15
# 🔍 Processing 8556/10000: /content/extracted_OCR_Dataset/Date-Synth/images/105518.jpg
# 📄 Extracted Text:
# SAUD/28/2020
# 🔍 Processing 8557/10000: /content/extracted_OCR_Dataset/Date-Synth/images/78713.jpg
# 📄 Extracted Text:
# 2900T2018
# 🔍 Processing 8558/10000: /content/extracted_OCR_Dataset/Date-Synth/images/117100.jpg
# 📄 Extracted Text:
# : 2014.AUG.24
# 🔍 Processing 8559/10000: /content/extracted_OCR_Dataset/Date-Synth/images/36745.jpg
# 📄 Extracted Text:
# 2024 11
# 🔍 Processing 8560/10000: /content/extracted_OCR_Dataset/Date-Synth/images/98366.jpg
# 📄 Extracted Text:
# -2020/12
# 🔍 Processing 8561/10000: /content/extracted_OCR_Dataset/Date-Synth/images/23849.jpg
# 📄 Extracted Text:
# 0.4-16
# 🔍 Processing 8562/10000: /content/extracted_OCR_Dataset/Date-Synth/images/96351.jpg
# 📄 Extracted Text:
# TIPN1420
# 🔍 Processing 8563/10000: /content/extracted_OCR_Dataset/Date-Synth/images/04686.jpg
# 📄 Extracted Text:
# 2022-MAY-02
# 🔍 Processing 8564/10000: /content/extracted_OCR_Dataset/Date-Synth/images/123781.jpg
# 📄 Extracted Text:
# 8 09.05
# 🔍 Processing 8565/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84146.jpg
# 📄 Extracted Text:
# 21-MAR-2015
# 🔍 Processing 8566/10000: /content/extracted_OCR_Dataset/Date-Synth/images/31031.jpg
# 📄 Extracted Text:
# NOV/08/2027
# 🔍 Processing 8567/10000: /content/extracted_OCR_Dataset/Date-Synth/images/125534.jpg
# 📄 Extracted Text:
# AUG-12-2018
# 🔍 Processing 8568/10000: /content/extracted_OCR_Dataset/Date-Synth/images/89475.jpg
# 📄 Extracted Text:
# 03 NOV 18
# 🔍 Processing 8569/10000: /content/extracted_OCR_Dataset/Date-Synth/images/26837.jpg
# 📄 Extracted Text:
# @0.9/08/80
# 🔍 Processing 8570/10000: /content/extracted_OCR_Dataset/Date-Synth/images/03923.jpg
# 📄 Extracted Text:
# 2016/12/20
# 🔍 Processing 8571/10000: /content/extracted_OCR_Dataset/Date-Synth/images/05581.jpg
# 📄 Extracted Text:
# 2024-JAN-14
# 🔍 Processing 8572/10000: /content/extracted_OCR_Dataset/Date-Synth/images/124833.jpg
# 📄 Extracted Text:
# 2017/05/26
# 🔍 Processing 8573/10000: /content/extracted_OCR_Dataset/Date-Synth/images/40199.jpg
# 📄 Extracted Text:
# 20.00.00
# 🔍 Processing 8574/10000: /content/extracted_OCR_Dataset/Date-Synth/images/85928.jpg
# 📄 Extracted Text:
# 08/2028"
# 🔍 Processing 8575/10000: /content/extracted_OCR_Dataset/Date-Synth/images/95478.jpg
# 📄 Extracted Text:
# MAR-19 2016
# 🔍 Processing 8576/10000: /content/extracted_OCR_Dataset/Date-Synth/images/44663.jpg
# 📄 Extracted Text:
# JUN/16.45
# 🔍 Processing 8577/10000: /content/extracted_OCR_Dataset/Date-Synth/images/28539.jpg
# 📄 Extracted Text:
# AMOUNT
# 🔍 Processing 8578/10000: /content/extracted_OCR_Dataset/Date-Synth/images/44026.jpg
# 📄 Extracted Text:
# MAY.03.23
# 🔍 Processing 8579/10000: /content/extracted_OCR_Dataset/Date-Synth/images/127039.jpg
# 📄 Extracted Text:
# 26|09|13
# 🔍 Processing 8580/10000: /content/extracted_OCR_Dataset/Date-Synth/images/108358.jpg
# 📄 Extracted Text:
# 2021 FEB 12 1
# 🔍 Processing 8581/10000: /content/extracted_OCR_Dataset/Date-Synth/images/64577.jpg
# 📄 Extracted Text:
# 2021/12/23
# 🔍 Processing 8582/10000: /content/extracted_OCR_Dataset/Date-Synth/images/93551.jpg
# 📄 Extracted Text:
# 2015 12:05
# 🔍 Processing 8583/10000: /content/extracted_OCR_Dataset/Date-Synth/images/20314.jpg
# 📄 Extracted Text:
# JAN-21-16
# 🔍 Processing 8584/10000: /content/extracted_OCR_Dataset/Date-Synth/images/77872.jpg
# 📄 Extracted Text:
# 20 FEB 19
# 🔍 Processing 8585/10000: /content/extracted_OCR_Dataset/Date-Synth/images/23730.jpg
# 📄 Extracted Text:
# 07.09
# 🔍 Processing 8586/10000: /content/extracted_OCR_Dataset/Date-Synth/images/04645.jpg
# 📄 Extracted Text:
# 2.0 1 2 F E B , 2 0
# 🔍 Processing 8587/10000: /content/extracted_OCR_Dataset/Date-Synth/images/06346.jpg
# 📄 Extracted Text:
# AUG.14.2019
# 🔍 Processing 8588/10000: /content/extracted_OCR_Dataset/Date-Synth/images/126114.jpg
# 📄 Extracted Text:
# 04-2028
# 🔍 Processing 8589/10000: /content/extracted_OCR_Dataset/Date-Synth/images/72835.jpg
# 📄 Extracted Text:
# 01-11-29
# 🔍 Processing 8590/10000: /content/extracted_OCR_Dataset/Date-Synth/images/10966.jpg
# 📄 Extracted Text:
# 12/2019
# 🔍 Processing 8591/10000: /content/extracted_OCR_Dataset/Date-Synth/images/100810.jpg
# 📄 Extracted Text:
# 49/03/06
# 🔍 Processing 8592/10000: /content/extracted_OCR_Dataset/Date-Synth/images/56158.jpg
# 📄 Extracted Text:
# FEB2023.
# 🔍 Processing 8593/10000: /content/extracted_OCR_Dataset/Date-Synth/images/90868.jpg
# 📄 Extracted Text:
# -DEC-29-28
# 🔍 Processing 8594/10000: /content/extracted_OCR_Dataset/Date-Synth/images/117809.jpg
# 📄 Extracted Text:
# FOCT.03.2016
# 🔍 Processing 8595/10000: /content/extracted_OCR_Dataset/Date-Synth/images/43236.jpg
# 📄 Extracted Text:
# 13/MAR/20
# 🔍 Processing 8596/10000: /content/extracted_OCR_Dataset/Date-Synth/images/36062.jpg
# 📄 Extracted Text:
# 2016-01
# 🔍 Processing 8597/10000: /content/extracted_OCR_Dataset/Date-Synth/images/113665.jpg
# 📄 Extracted Text:
# 19.MAR.21E
# 🔍 Processing 8598/10000: /content/extracted_OCR_Dataset/Date-Synth/images/73331.jpg
# 📄 Extracted Text:
# 12.02.20224
# 🔍 Processing 8599/10000: /content/extracted_OCR_Dataset/Date-Synth/images/74902.jpg
# 📄 Extracted Text:
# 110914
# 🔍 Processing 8600/10000: /content/extracted_OCR_Dataset/Date-Synth/images/100339.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 8601/10000: /content/extracted_OCR_Dataset/Date-Synth/images/123146.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 8602/10000: /content/extracted_OCR_Dataset/Date-Synth/images/79843.jpg
# 📄 Extracted Text:
# 2015/02/02
# 🔍 Processing 8603/10000: /content/extracted_OCR_Dataset/Date-Synth/images/17222.jpg
# 📄 Extracted Text:
# 12:09:42
# 🔍 Processing 8604/10000: /content/extracted_OCR_Dataset/Date-Synth/images/18961.jpg
# 📄 Extracted Text:
# 10 / NIO V/ 2 0
# 🔍 Processing 8605/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84440.jpg
# 📄 Extracted Text:
# :06 NOV 2025
# 🔍 Processing 8606/10000: /content/extracted_OCR_Dataset/Date-Synth/images/41134.jpg
# 📄 Extracted Text:
# 19/06/13
# 🔍 Processing 8607/10000: /content/extracted_OCR_Dataset/Date-Synth/images/101232.jpg
# 📄 Extracted Text:
# 29-NOV-29-
# 🔍 Processing 8608/10000: /content/extracted_OCR_Dataset/Date-Synth/images/47690.jpg
# 📄 Extracted Text:
# OMPLE
# 🔍 Processing 8609/10000: /content/extracted_OCR_Dataset/Date-Synth/images/06086.jpg
# 📄 Extracted Text:
# MAY/23/2012
# 🔍 Processing 8610/10000: /content/extracted_OCR_Dataset/Date-Synth/images/117872.jpg
# 📄 Extracted Text:
# ROUND A 2826
# 🔍 Processing 8611/10000: /content/extracted_OCR_Dataset/Date-Synth/images/72224.jpg
# 📄 Extracted Text:
# 05008124
# 🔍 Processing 8612/10000: /content/extracted_OCR_Dataset/Date-Synth/images/09732.jpg
# 📄 Extracted Text:
# 11/OCT/2024
# 🔍 Processing 8613/10000: /content/extracted_OCR_Dataset/Date-Synth/images/04329.jpg
# 📄 Extracted Text:
# 2022-NOV-03
# 🔍 Processing 8614/10000: /content/extracted_OCR_Dataset/Date-Synth/images/91123.jpg
# 📄 Extracted Text:
# 03-10
# 🔍 Processing 8615/10000: /content/extracted_OCR_Dataset/Date-Synth/images/98484.jpg
# 📄 Extracted Text:
# 2027.04
# 🔍 Processing 8616/10000: /content/extracted_OCR_Dataset/Date-Synth/images/113774.jpg
# 📄 Extracted Text:
# 27/DEC/27 G
# 🔍 Processing 8617/10000: /content/extracted_OCR_Dataset/Date-Synth/images/15655.jpg
# 📄 Extracted Text:
# SEP 2027
# 🔍 Processing 8618/10000: /content/extracted_OCR_Dataset/Date-Synth/images/86314.jpg
# 📄 Extracted Text:
# 2012.06
# 🔍 Processing 8619/10000: /content/extracted_OCR_Dataset/Date-Synth/images/44883.jpg
# 📄 Extracted Text:
# NOV-04-07
# 🔍 Processing 8620/10000: /content/extracted_OCR_Dataset/Date-Synth/images/15495.jpg
# 📄 Extracted Text:
# JAN/2018
# 🔍 Processing 8621/10000: /content/extracted_OCR_Dataset/Date-Synth/images/30473.jpg
# 📄 Extracted Text:
# FEB/11/2015
# 🔍 Processing 8622/10000: /content/extracted_OCR_Dataset/Date-Synth/images/66370.jpg
# 📄 Extracted Text:
# @ 15.00 AM
# 🔍 Processing 8623/10000: /content/extracted_OCR_Dataset/Date-Synth/images/47202.jpg
# 📄 Extracted Text:
# 02.49
# 🔍 Processing 8624/10000: /content/extracted_OCR_Dataset/Date-Synth/images/10053.jpg
# 📄 Extracted Text:
# 05.2017
# 🔍 Processing 8625/10000: /content/extracted_OCR_Dataset/Date-Synth/images/44670.jpg
# 📄 Extracted Text:
# MAY-08-26
# 🔍 Processing 8626/10000: /content/extracted_OCR_Dataset/Date-Synth/images/25103.jpg
# 📄 Extracted Text:
# 14/-0- 2 0:21
# 🔍 Processing 8627/10000: /content/extracted_OCR_Dataset/Date-Synth/images/107855.jpg
# 📄 Extracted Text:
# PUR-IDGE
# 🔍 Processing 8628/10000: /content/extracted_OCR_Dataset/Date-Synth/images/126651.jpg
# 📄 Extracted Text:
# : 42024
# 🔍 Processing 8629/10000: /content/extracted_OCR_Dataset/Date-Synth/images/102080.jpg
# 📄 Extracted Text:
# OCT-05-21
# 🔍 Processing 8630/10000: /content/extracted_OCR_Dataset/Date-Synth/images/98327.jpg
# 📄 Extracted Text:
# 2 0 2 6 / 0 1
# 🔍 Processing 8631/10000: /content/extracted_OCR_Dataset/Date-Synth/images/53547.jpg
# 📄 Extracted Text:
# 10JUL2024
# 🔍 Processing 8632/10000: /content/extracted_OCR_Dataset/Date-Synth/images/77378.jpg
# 📄 Extracted Text:
# 2018-10
# 🔍 Processing 8633/10000: /content/extracted_OCR_Dataset/Date-Synth/images/108944.jpg
# 📄 Extracted Text:
# MAY-09-2017B
# 🔍 Processing 8634/10000: /content/extracted_OCR_Dataset/Date-Synth/images/38788.jpg
# 📄 Extracted Text:
# DEC 2014
# 🔍 Processing 8635/10000: /content/extracted_OCR_Dataset/Date-Synth/images/49314.jpg
# 📄 Extracted Text:
# AUG162015
# 🔍 Processing 8636/10000: /content/extracted_OCR_Dataset/Date-Synth/images/83936.jpg
# 📄 Extracted Text:
# FEB-14-2015
# 🔍 Processing 8637/10000: /content/extracted_OCR_Dataset/Date-Synth/images/08291.jpg
# 📄 Extracted Text:
# 01 OCT 2016
# 🔍 Processing 8638/10000: /content/extracted_OCR_Dataset/Date-Synth/images/06945.jpg
# 📄 Extracted Text:
# JUN 22/2012
# 🔍 Processing 8639/10000: /content/extracted_OCR_Dataset/Date-Synth/images/118570.jpg
# 📄 Extracted Text:
# :25, FEB 2012
# 🔍 Processing 8640/10000: /content/extracted_OCR_Dataset/Date-Synth/images/57991.jpg
# 📄 Extracted Text:
# AMOUNT
# 🔍 Processing 8641/10000: /content/extracted_OCR_Dataset/Date-Synth/images/110848.jpg
# 📄 Extracted Text:
# 07/2027D
# 🔍 Processing 8642/10000: /content/extracted_OCR_Dataset/Date-Synth/images/76387.jpg
# 📄 Extracted Text:
# 2024 02 01
# 🔍 Processing 8643/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84942.jpg
# 📄 Extracted Text:
# 20 JAN 2017
# 🔍 Processing 8644/10000: /content/extracted_OCR_Dataset/Date-Synth/images/03328.jpg
# 📄 Extracted Text:
# 2015 01 11
# 🔍 Processing 8645/10000: /content/extracted_OCR_Dataset/Date-Synth/images/57000.jpg
# 📄 Extracted Text:
# AUG2026
# 🔍 Processing 8646/10000: /content/extracted_OCR_Dataset/Date-Synth/images/47096.jpg
# 📄 Extracted Text:
# CHS
# 🔍 Processing 8647/10000: /content/extracted_OCR_Dataset/Date-Synth/images/39314.jpg
# 📄 Extracted Text:
# PUL =20.27
# 🔍 Processing 8648/10000: /content/extracted_OCR_Dataset/Date-Synth/images/75284.jpg
# 📄 Extracted Text:
# 2017/04/02
# 🔍 Processing 8649/10000: /content/extracted_OCR_Dataset/Date-Synth/images/114315.jpg
# 📄 Extracted Text:
# ( MAR) 14/19
# 🔍 Processing 8650/10000: /content/extracted_OCR_Dataset/Date-Synth/images/99474.jpg
# 📄 Extracted Text:
# : OCT 2026
# 🔍 Processing 8651/10000: /content/extracted_OCR_Dataset/Date-Synth/images/01107.jpg
# 📄 Extracted Text:
# 31.09 2027
# 🔍 Processing 8652/10000: /content/extracted_OCR_Dataset/Date-Synth/images/23198.jpg
# 📄 Extracted Text:
# 05-97
# 🔍 Processing 8653/10000: /content/extracted_OCR_Dataset/Date-Synth/images/83522.jpg
# 📄 Extracted Text:
# MAR 06 2026
# 🔍 Processing 8654/10000: /content/extracted_OCR_Dataset/Date-Synth/images/62635.jpg
# 📄 Extracted Text:
# 27/062014
# 🔍 Processing 8655/10000: /content/extracted_OCR_Dataset/Date-Synth/images/54847.jpg
# 📄 Extracted Text:
# 20160AR30
# 🔍 Processing 8656/10000: /content/extracted_OCR_Dataset/Date-Synth/images/119435.jpg
# 📄 Extracted Text:
# 10-20246
# 🔍 Processing 8657/10000: /content/extracted_OCR_Dataset/Date-Synth/images/122834.jpg
# 📄 Extracted Text:
# 13/NOV/29/
# 🔍 Processing 8658/10000: /content/extracted_OCR_Dataset/Date-Synth/images/46006.jpg
# 📄 Extracted Text:
# 0.97
# 🔍 Processing 8659/10000: /content/extracted_OCR_Dataset/Date-Synth/images/100006.jpg
# 📄 Extracted Text:
# (9) 1 M PLAN 2.8
# 🔍 Processing 8660/10000: /content/extracted_OCR_Dataset/Date-Synth/images/46296.jpg
# 📄 Extracted Text:
# @0.15
# 🔍 Processing 8661/10000: /content/extracted_OCR_Dataset/Date-Synth/images/04473.jpg
# 📄 Extracted Text:
# 2018-FEB-25
# 🔍 Processing 8662/10000: /content/extracted_OCR_Dataset/Date-Synth/images/90703.jpg
# 📄 Extracted Text:
# : SEP#12126
# 🔍 Processing 8663/10000: /content/extracted_OCR_Dataset/Date-Synth/images/62877.jpg
# 📄 Extracted Text:
# 19/10/2022
# 🔍 Processing 8664/10000: /content/extracted_OCR_Dataset/Date-Synth/images/58688.jpg
# 📄 Extracted Text:
# 2022/11/26
# 🔍 Processing 8665/10000: /content/extracted_OCR_Dataset/Date-Synth/images/124506.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 8666/10000: /content/extracted_OCR_Dataset/Date-Synth/images/121590.jpg
# 📄 Extracted Text:
# 2.50"07-2.27
# 🔍 Processing 8667/10000: /content/extracted_OCR_Dataset/Date-Synth/images/101520.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 8668/10000: /content/extracted_OCR_Dataset/Date-Synth/images/117277.jpg
# 📄 Extracted Text:
# 2029.SEP.15A
# 🔍 Processing 8669/10000: /content/extracted_OCR_Dataset/Date-Synth/images/18278.jpg
# 📄 Extracted Text:
# 20,APR.21
# 🔍 Processing 8670/10000: /content/extracted_OCR_Dataset/Date-Synth/images/70480.jpg
# 📄 Extracted Text:
# 03.01.2022
# 🔍 Processing 8671/10000: /content/extracted_OCR_Dataset/Date-Synth/images/96529.jpg
# 📄 Extracted Text:
# (M)COMPANY
# 🔍 Processing 8672/10000: /content/extracted_OCR_Dataset/Date-Synth/images/37023.jpg
# 📄 Extracted Text:
# 20.29-12
# 🔍 Processing 8673/10000: /content/extracted_OCR_Dataset/Date-Synth/images/110480.jpg
# 📄 Extracted Text:
# 01.20167
# 🔍 Processing 8674/10000: /content/extracted_OCR_Dataset/Date-Synth/images/104555.jpg
# 📄 Extracted Text:
# 02-2022
# 🔍 Processing 8675/10000: /content/extracted_OCR_Dataset/Date-Synth/images/118380.jpg
# 📄 Extracted Text:
# AE@B=04:2026
# 🔍 Processing 8676/10000: /content/extracted_OCR_Dataset/Date-Synth/images/114821.jpg
# 📄 Extracted Text:
# : 02.11
# 🔍 Processing 8677/10000: /content/extracted_OCR_Dataset/Date-Synth/images/00343.jpg
# 📄 Extracted Text:
# 2.6 / 0 8 /:2 0/2 8
# 🔍 Processing 8678/10000: /content/extracted_OCR_Dataset/Date-Synth/images/123410.jpg
# 📄 Extracted Text:
# JUL 23-07
# 🔍 Processing 8679/10000: /content/extracted_OCR_Dataset/Date-Synth/images/69882.jpg
# 📄 Extracted Text:
# :
# 🔍 Processing 8680/10000: /content/extracted_OCR_Dataset/Date-Synth/images/74096.jpg
# 📄 Extracted Text:
# 6@-10-00
# 🔍 Processing 8681/10000: /content/extracted_OCR_Dataset/Date-Synth/images/30626.jpg
# 📄 Extracted Text:
# J@://28/2018
# 🔍 Processing 8682/10000: /content/extracted_OCR_Dataset/Date-Synth/images/116850.jpg
# 📄 Extracted Text:
# HAX 1.04
# 🔍 Processing 8683/10000: /content/extracted_OCR_Dataset/Date-Synth/images/78683.jpg
# 📄 Extracted Text:
# JANI52018
# 🔍 Processing 8684/10000: /content/extracted_OCR_Dataset/Date-Synth/images/11618.jpg
# 📄 Extracted Text:
# 03.2015
# 🔍 Processing 8685/10000: /content/extracted_OCR_Dataset/Date-Synth/images/89438.jpg
# 📄 Extracted Text:
# 18 OCT 27
# 🔍 Processing 8686/10000: /content/extracted_OCR_Dataset/Date-Synth/images/91888.jpg
# 📄 Extracted Text:
# 10.20
# 🔍 Processing 8687/10000: /content/extracted_OCR_Dataset/Date-Synth/images/00087.jpg
# 📄 Extracted Text:
# Q5-06-2022
# 🔍 Processing 8688/10000: /content/extracted_OCR_Dataset/Date-Synth/images/40083.jpg
# 📄 Extracted Text:
# @18/03/13
# 🔍 Processing 8689/10000: /content/extracted_OCR_Dataset/Date-Synth/images/14280.jpg
# 📄 Extracted Text:
# FEB/2026
# 🔍 Processing 8690/10000: /content/extracted_OCR_Dataset/Date-Synth/images/87976.jpg
# 📄 Extracted Text:
# JUN 2024
# 🔍 Processing 8691/10000: /content/extracted_OCR_Dataset/Date-Synth/images/87318.jpg
# 📄 Extracted Text:
# SEP/2028
# 🔍 Processing 8692/10000: /content/extracted_OCR_Dataset/Date-Synth/images/50691.jpg
# 📄 Extracted Text:
# OCT1826
# 🔍 Processing 8693/10000: /content/extracted_OCR_Dataset/Date-Synth/images/53524.jpg
# 📄 Extracted Text:
# FEB222027
# 🔍 Processing 8694/10000: /content/extracted_OCR_Dataset/Date-Synth/images/34846.jpg
# 📄 Extracted Text:
# 08-2029
# 🔍 Processing 8695/10000: /content/extracted_OCR_Dataset/Date-Synth/images/26313.jpg
# 📄 Extracted Text:
# PLEASE
# 🔍 Processing 8696/10000: /content/extracted_OCR_Dataset/Date-Synth/images/58992.jpg
# 📄 Extracted Text:
# 2026404478
# 🔍 Processing 8697/10000: /content/extracted_OCR_Dataset/Date-Synth/images/98247.jpg
# 📄 Extracted Text:
# 2044%@6!
# 🔍 Processing 8698/10000: /content/extracted_OCR_Dataset/Date-Synth/images/83978.jpg
# 📄 Extracted Text:
# TEL:02T-12012
# 🔍 Processing 8699/10000: /content/extracted_OCR_Dataset/Date-Synth/images/25637.jpg
# 📄 Extracted Text:
# 28/02/2028
# 🔍 Processing 8700/10000: /content/extracted_OCR_Dataset/Date-Synth/images/73046.jpg
# 📄 Extracted Text:
# 2017/11/03
# 🔍 Processing 8701/10000: /content/extracted_OCR_Dataset/Date-Synth/images/15250.jpg
# 📄 Extracted Text:
# MAR/2014
# 🔍 Processing 8702/10000: /content/extracted_OCR_Dataset/Date-Synth/images/90454.jpg
# 📄 Extracted Text:
# DEC/05/24
# 🔍 Processing 8703/10000: /content/extracted_OCR_Dataset/Date-Synth/images/81802.jpg
# 📄 Extracted Text:
# : 2026/06/05
# 🔍 Processing 8704/10000: /content/extracted_OCR_Dataset/Date-Synth/images/46888.jpg
# 📄 Extracted Text:
# 05.19
# 🔍 Processing 8705/10000: /content/extracted_OCR_Dataset/Date-Synth/images/47627.jpg
# 📄 Extracted Text:
# 09/28
# 🔍 Processing 8706/10000: /content/extracted_OCR_Dataset/Date-Synth/images/100583.jpg
# 📄 Extracted Text:
# 04.09:09
# 🔍 Processing 8707/10000: /content/extracted_OCR_Dataset/Date-Synth/images/34394.jpg
# 📄 Extracted Text:
# MY.COM
# 🔍 Processing 8708/10000: /content/extracted_OCR_Dataset/Date-Synth/images/30964.jpg
# 📄 Extracted Text:
# APR-26-2028
# 🔍 Processing 8709/10000: /content/extracted_OCR_Dataset/Date-Synth/images/32883.jpg
# 📄 Extracted Text:
# 25,JUL 2026
# 🔍 Processing 8710/10000: /content/extracted_OCR_Dataset/Date-Synth/images/93008.jpg
# 📄 Extracted Text:
# KEYCASHIER
# 🔍 Processing 8711/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84711.jpg
# 📄 Extracted Text:
# 04-AUG-2021
# 🔍 Processing 8712/10000: /content/extracted_OCR_Dataset/Date-Synth/images/101394.jpg
# 📄 Extracted Text:
# 05 OCT 28
# 🔍 Processing 8713/10000: /content/extracted_OCR_Dataset/Date-Synth/images/15475.jpg
# 📄 Extracted Text:
# SEP/2013
# 🔍 Processing 8714/10000: /content/extracted_OCR_Dataset/Date-Synth/images/119122.jpg
# 📄 Extracted Text:
# 003 F@B 2028
# 🔍 Processing 8715/10000: /content/extracted_OCR_Dataset/Date-Synth/images/96903.jpg
# 📄 Extracted Text:
# SR JALANANANAN
# 🔍 Processing 8716/10000: /content/extracted_OCR_Dataset/Date-Synth/images/65218.jpg
# 📄 Extracted Text:
# 14/10/2022
# 🔍 Processing 8717/10000: /content/extracted_OCR_Dataset/Date-Synth/images/30351.jpg
# 📄 Extracted Text:
# REF: 10:29:04
# 🔍 Processing 8718/10000: /content/extracted_OCR_Dataset/Date-Synth/images/111973.jpg
# 📄 Extracted Text:
# MAR 2015 E
# 🔍 Processing 8719/10000: /content/extracted_OCR_Dataset/Date-Synth/images/82964.jpg
# 📄 Extracted Text:
# 2018/NOV /06
# 🔍 Processing 8720/10000: /content/extracted_OCR_Dataset/Date-Synth/images/24303.jpg
# 📄 Extracted Text:
# 12:06:2019
# 🔍 Processing 8721/10000: /content/extracted_OCR_Dataset/Date-Synth/images/73830.jpg
# 📄 Extracted Text:
# 2023/09/09
# 🔍 Processing 8722/10000: /content/extracted_OCR_Dataset/Date-Synth/images/113615.jpg
# 📄 Extracted Text:
# 31 APR 17H
# 🔍 Processing 8723/10000: /content/extracted_OCR_Dataset/Date-Synth/images/123822.jpg
# 📄 Extracted Text:
# AUGG
# 🔍 Processing 8724/10000: /content/extracted_OCR_Dataset/Date-Synth/images/112503.jpg
# 📄 Extracted Text:
# :19/08/26
# 🔍 Processing 8725/10000: /content/extracted_OCR_Dataset/Date-Synth/images/31000.jpg
# 📄 Extracted Text:
# JUN.02.2023
# 🔍 Processing 8726/10000: /content/extracted_OCR_Dataset/Date-Synth/images/19243.jpg
# 📄 Extracted Text:
# 17/SEP/23
# 🔍 Processing 8727/10000: /content/extracted_OCR_Dataset/Date-Synth/images/79050.jpg
# 📄 Extracted Text:
# 2026/10/29
# 🔍 Processing 8728/10000: /content/extracted_OCR_Dataset/Date-Synth/images/65798.jpg
# 📄 Extracted Text:
# : *(P/07/17
# 🔍 Processing 8729/10000: /content/extracted_OCR_Dataset/Date-Synth/images/70253.jpg
# 📄 Extracted Text:
# 2023/09/01
# 🔍 Processing 8730/10000: /content/extracted_OCR_Dataset/Date-Synth/images/73882.jpg
# 📄 Extracted Text:
# 04-01-2025
# 🔍 Processing 8731/10000: /content/extracted_OCR_Dataset/Date-Synth/images/90585.jpg
# 📄 Extracted Text:
# JAN-M-23
# 🔍 Processing 8732/10000: /content/extracted_OCR_Dataset/Date-Synth/images/99268.jpg
# 📄 Extracted Text:
# INVO.2027
# 🔍 Processing 8733/10000: /content/extracted_OCR_Dataset/Date-Synth/images/52212.jpg
# 📄 Extracted Text:
# FEBI72021
# 🔍 Processing 8734/10000: /content/extracted_OCR_Dataset/Date-Synth/images/117647.jpg
# 📄 Extracted Text:
# : 2027AUG.03
# 🔍 Processing 8735/10000: /content/extracted_OCR_Dataset/Date-Synth/images/72504.jpg
# 📄 Extracted Text:
# 17-12-07
# 🔍 Processing 8736/10000: /content/extracted_OCR_Dataset/Date-Synth/images/66957.jpg
# 📄 Extracted Text:
# 28/06/2028
# 🔍 Processing 8737/10000: /content/extracted_OCR_Dataset/Date-Synth/images/105237.jpg
# 📄 Extracted Text:
# 6 12/02/2026
# 🔍 Processing 8738/10000: /content/extracted_OCR_Dataset/Date-Synth/images/92064.jpg
# 📄 Extracted Text:
# 24012016
# 🔍 Processing 8739/10000: /content/extracted_OCR_Dataset/Date-Synth/images/76594.jpg
# 📄 Extracted Text:
# 2012.000.29
# 🔍 Processing 8740/10000: /content/extracted_OCR_Dataset/Date-Synth/images/43473.jpg
# 📄 Extracted Text:
# 29 MAR 19
# 🔍 Processing 8741/10000: /content/extracted_OCR_Dataset/Date-Synth/images/13817.jpg
# 📄 Extracted Text:
# 2024 07
# 🔍 Processing 8742/10000: /content/extracted_OCR_Dataset/Date-Synth/images/66384.jpg
# 📄 Extracted Text:
# 22/10/2028
# 🔍 Processing 8743/10000: /content/extracted_OCR_Dataset/Date-Synth/images/34133.jpg
# 📄 Extracted Text:
# 08 2023
# 🔍 Processing 8744/10000: /content/extracted_OCR_Dataset/Date-Synth/images/48112.jpg
# 📄 Extracted Text:
# JUN312013
# 🔍 Processing 8745/10000: /content/extracted_OCR_Dataset/Date-Synth/images/74467.jpg
# 📄 Extracted Text:
# 07 03.02
# 🔍 Processing 8746/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84207.jpg
# 📄 Extracted Text:
# (27/SEP/2014
# 🔍 Processing 8747/10000: /content/extracted_OCR_Dataset/Date-Synth/images/88502.jpg
# 📄 Extracted Text:
# *0 1.71% @ 2.4
# 🔍 Processing 8748/10000: /content/extracted_OCR_Dataset/Date-Synth/images/122111.jpg
# 📄 Extracted Text:
# (18 01 05
# 🔍 Processing 8749/10000: /content/extracted_OCR_Dataset/Date-Synth/images/106476.jpg
# 📄 Extracted Text:
# 27.07.2017 D
# 🔍 Processing 8750/10000: /content/extracted_OCR_Dataset/Date-Synth/images/53783.jpg
# 📄 Extracted Text:
# DEC202F
# 🔍 Processing 8751/10000: /content/extracted_OCR_Dataset/Date-Synth/images/40027.jpg
# 📄 Extracted Text:
# 13/06/08
# 🔍 Processing 8752/10000: /content/extracted_OCR_Dataset/Date-Synth/images/08347.jpg
# 📄 Extracted Text:
# 2/2-5 II-0 V2.2 0-1:2
# 🔍 Processing 8753/10000: /content/extracted_OCR_Dataset/Date-Synth/images/112290.jpg
# 📄 Extracted Text:
# DEC/2028:
# 🔍 Processing 8754/10000: /content/extracted_OCR_Dataset/Date-Synth/images/115171.jpg
# 📄 Extracted Text:
# 08/14 *
# 🔍 Processing 8755/10000: /content/extracted_OCR_Dataset/Date-Synth/images/88543.jpg
# 📄 Extracted Text:
# 18/18/29
# 🔍 Processing 8756/10000: /content/extracted_OCR_Dataset/Date-Synth/images/14306.jpg
# 📄 Extracted Text:
# SEP/2013
# 🔍 Processing 8757/10000: /content/extracted_OCR_Dataset/Date-Synth/images/105767.jpg
# 📄 Extracted Text:
# 65/2017 D
# 🔍 Processing 8758/10000: /content/extracted_OCR_Dataset/Date-Synth/images/75218.jpg
# 📄 Extracted Text:
# 12-11-2017
# 🔍 Processing 8759/10000: /content/extracted_OCR_Dataset/Date-Synth/images/116148.jpg
# 📄 Extracted Text:
# 09-04-00250
# 🔍 Processing 8760/10000: /content/extracted_OCR_Dataset/Date-Synth/images/20764.jpg
# 📄 Extracted Text:
# REFN2917
# 🔍 Processing 8761/10000: /content/extracted_OCR_Dataset/Date-Synth/images/10454.jpg
# ...
# 📄 Extracted Text:
# 2027/04/19
# 🔍 Processing 9860/10000: /content/extracted_OCR_Dataset/Date-Synth/images/32018.jpg
# 📄 Extracted Text:
# 09-A06-2024
# 🔍 Processing 9861/10000: /content/extracted_OCR_Dataset/Date-Synth/images/60237.jpg
# 📄 Extracted Text:
# 20 22-06
# 🔍 Processing 9862/10000: /content/extracted_OCR_Dataset/Date-Synth/images/45595.jpg
# 📄 Extracted Text:
# NOV 05:22
# 🔍 Processing 9863/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84361.jpg
# 📄 Extracted Text:
# :08/OCT/8016
# 🔍 Processing 9864/10000: /content/extracted_OCR_Dataset/Date-Synth/images/99935.jpg
# 📄 Extracted Text:
# :
# 🔍 Processing 9865/10000: /content/extracted_OCR_Dataset/Date-Synth/images/26934.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 9866/10000: /content/extracted_OCR_Dataset/Date-Synth/images/110728.jpg
# 📄 Extracted Text:
# 05.2027:
# 🔍 Processing 9867/10000: /content/extracted_OCR_Dataset/Date-Synth/images/03590.jpg
# 📄 Extracted Text:
# 2014.03.22
# 🔍 Processing 9868/10000: /content/extracted_OCR_Dataset/Date-Synth/images/62333.jpg
# 📄 Extracted Text:
# 15/09(20.29)
# 🔍 Processing 9869/10000: /content/extracted_OCR_Dataset/Date-Synth/images/96853.jpg
# 📄 Extracted Text:
# 12/DEC/2029
# 🔍 Processing 9870/10000: /content/extracted_OCR_Dataset/Date-Synth/images/41695.jpg
# 📄 Extracted Text:
# SOMOLOB
# 🔍 Processing 9871/10000: /content/extracted_OCR_Dataset/Date-Synth/images/21041.jpg
# 📄 Extracted Text:
# OCT-13-28
# 🔍 Processing 9872/10000: /content/extracted_OCR_Dataset/Date-Synth/images/24977.jpg
# 📄 Extracted Text:
# @0.05 2005
# 🔍 Processing 9873/10000: /content/extracted_OCR_Dataset/Date-Synth/images/89722.jpg
# 📄 Extracted Text:
# 03 JAN 18
# 🔍 Processing 9874/10000: /content/extracted_OCR_Dataset/Date-Synth/images/96641.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 9875/10000: /content/extracted_OCR_Dataset/Date-Synth/images/88646.jpg
# 📄 Extracted Text:
# 20/02/18
# 🔍 Processing 9876/10000: /content/extracted_OCR_Dataset/Date-Synth/images/103523.jpg
# 📄 Extracted Text:
# -10:/ F0
# 🔍 Processing 9877/10000: /content/extracted_OCR_Dataset/Date-Synth/images/115707.jpg
# 📄 Extracted Text:
# 30.06.2027:
# 🔍 Processing 9878/10000: /content/extracted_OCR_Dataset/Date-Synth/images/75740.jpg
# 📄 Extracted Text:
# 11/11/2024
# 🔍 Processing 9879/10000: /content/extracted_OCR_Dataset/Date-Synth/images/108716.jpg
# 📄 Extracted Text:
# SEP: 10 2018%
# 🔍 Processing 9880/10000: /content/extracted_OCR_Dataset/Date-Synth/images/105700.jpg
# 📄 Extracted Text:
# 02.2014
# 🔍 Processing 9881/10000: /content/extracted_OCR_Dataset/Date-Synth/images/16249.jpg
# 📄 Extracted Text:
# 24 11 23
# 🔍 Processing 9882/10000: /content/extracted_OCR_Dataset/Date-Synth/images/69816.jpg
# 📄 Extracted Text:
# 2028-12-20
# 🔍 Processing 9883/10000: /content/extracted_OCR_Dataset/Date-Synth/images/28688.jpg
# 📄 Extracted Text:
# 2014 NOV 02
# 🔍 Processing 9884/10000: /content/extracted_OCR_Dataset/Date-Synth/images/13417.jpg
# 📄 Extracted Text:
# 2023.12
# 🔍 Processing 9885/10000: /content/extracted_OCR_Dataset/Date-Synth/images/92245.jpg
# 📄 Extracted Text:
# 20/09:003
# 🔍 Processing 9886/10000: /content/extracted_OCR_Dataset/Date-Synth/images/125366.jpg
# 📄 Extracted Text:
# JAN / 0 6 / 2 0 2'4
# 🔍 Processing 9887/10000: /content/extracted_OCR_Dataset/Date-Synth/images/54957.jpg
# 📄 Extracted Text:
# 22NOV2012
# 🔍 Processing 9888/10000: /content/extracted_OCR_Dataset/Date-Synth/images/11319.jpg
# 📄 Extracted Text:
# 08.2015
# 🔍 Processing 9889/10000: /content/extracted_OCR_Dataset/Date-Synth/images/45160.jpg
# 📄 Extracted Text:
# JUN-06-15
# 🔍 Processing 9890/10000: /content/extracted_OCR_Dataset/Date-Synth/images/18462.jpg
# 📄 Extracted Text:
# 04.SEP.15
# 🔍 Processing 9891/10000: /content/extracted_OCR_Dataset/Date-Synth/images/09365.jpg
# 📄 Extracted Text:
# 12 FEB 2014
# 🔍 Processing 9892/10000: /content/extracted_OCR_Dataset/Date-Synth/images/17898.jpg
# 📄 Extracted Text:
# 05-08-12
# 🔍 Processing 9893/10000: /content/extracted_OCR_Dataset/Date-Synth/images/87387.jpg
# 📄 Extracted Text:
# JAN/2014
# 🔍 Processing 9894/10000: /content/extracted_OCR_Dataset/Date-Synth/images/126286.jpg
# 📄 Extracted Text:
# - 01-07
# 🔍 Processing 9895/10000: /content/extracted_OCR_Dataset/Date-Synth/images/25226.jpg
# 📄 Extracted Text:
# 27/08/20:23
# 🔍 Processing 9896/10000: /content/extracted_OCR_Dataset/Date-Synth/images/19334.jpg
# 📄 Extracted Text:
# 10.001.29
# 🔍 Processing 9897/10000: /content/extracted_OCR_Dataset/Date-Synth/images/54081.jpg
# 📄 Extracted Text:
# JUN0627
# 🔍 Processing 9898/10000: /content/extracted_OCR_Dataset/Date-Synth/images/46414.jpg
# 📄 Extracted Text:
# 07/24
# 🔍 Processing 9899/10000: /content/extracted_OCR_Dataset/Date-Synth/images/97507.jpg
# 📄 Extracted Text:
# 02,2014
# 🔍 Processing 9900/10000: /content/extracted_OCR_Dataset/Date-Synth/images/69101.jpg
# 📄 Extracted Text:
# 27/12/2012
# 🔍 Processing 9901/10000: /content/extracted_OCR_Dataset/Date-Synth/images/01247.jpg
# 📄 Extracted Text:
# 18.12.2027
# 🔍 Processing 9902/10000: /content/extracted_OCR_Dataset/Date-Synth/images/120995.jpg
# 📄 Extracted Text:
# PAULIPNS
# 🔍 Processing 9903/10000: /content/extracted_OCR_Dataset/Date-Synth/images/99964.jpg
# 📄 Extracted Text:
# CASH
# 🔍 Processing 9904/10000: /content/extracted_OCR_Dataset/Date-Synth/images/114347.jpg
# 📄 Extracted Text:
# CNOV 21 16
# 🔍 Processing 9905/10000: /content/extracted_OCR_Dataset/Date-Synth/images/62885.jpg
# 📄 Extracted Text:
# 2028-02-30
# 🔍 Processing 9906/10000: /content/extracted_OCR_Dataset/Date-Synth/images/59337.jpg
# 📄 Extracted Text:
# 2021 - NOV - 17
# 🔍 Processing 9907/10000: /content/extracted_OCR_Dataset/Date-Synth/images/104825.jpg
# 📄 Extracted Text:
# 06 12-01
# 🔍 Processing 9908/10000: /content/extracted_OCR_Dataset/Date-Synth/images/101066.jpg
# 📄 Extracted Text:
# 02.DEC.15
# 🔍 Processing 9909/10000: /content/extracted_OCR_Dataset/Date-Synth/images/68567.jpg
# 📄 Extracted Text:
# 2080508
# 🔍 Processing 9910/10000: /content/extracted_OCR_Dataset/Date-Synth/images/104197.jpg
# 📄 Extracted Text:
# 2018:08:14
# 🔍 Processing 9911/10000: /content/extracted_OCR_Dataset/Date-Synth/images/41318.jpg
# 📄 Extracted Text:
# 29/03/02
# 🔍 Processing 9912/10000: /content/extracted_OCR_Dataset/Date-Synth/images/32343.jpg
# 📄 Extracted Text:
# 08-OCT-2026
# 🔍 Processing 9913/10000: /content/extracted_OCR_Dataset/Date-Synth/images/118324.jpg
# 📄 Extracted Text:
# KA00.0025/VEAUR/FREE
# 🔍 Processing 9914/10000: /content/extracted_OCR_Dataset/Date-Synth/images/123051.jpg
# 📄 Extracted Text:
# BINAL/28/20
# 🔍 Processing 9915/10000: /content/extracted_OCR_Dataset/Date-Synth/images/25988.jpg
# 📄 Extracted Text:
# 09401,2014
# 🔍 Processing 9916/10000: /content/extracted_OCR_Dataset/Date-Synth/images/92448.jpg
# 📄 Extracted Text:
# 26.04.2029 *
# 🔍 Processing 9917/10000: /content/extracted_OCR_Dataset/Date-Synth/images/35298.jpg
# 📄 Extracted Text:
# 06/2028
# 🔍 Processing 9918/10000: /content/extracted_OCR_Dataset/Date-Synth/images/52900.jpg
# 📄 Extracted Text:
# AUG2020
# 🔍 Processing 9919/10000: /content/extracted_OCR_Dataset/Date-Synth/images/49548.jpg
# 📄 Extracted Text:
# 14DEC22
# 🔍 Processing 9920/10000: /content/extracted_OCR_Dataset/Date-Synth/images/08091.jpg
# 📄 Extracted Text:
# 13 MAR.2027
# 🔍 Processing 9921/10000: /content/extracted_OCR_Dataset/Date-Synth/images/54031.jpg
# 📄 Extracted Text:
# AUG052/
# 🔍 Processing 9922/10000: /content/extracted_OCR_Dataset/Date-Synth/images/82120.jpg
# 📄 Extracted Text:
# 2027-JUN-23
# 🔍 Processing 9923/10000: /content/extracted_OCR_Dataset/Date-Synth/images/97532.jpg
# 📄 Extracted Text:
# 07:2024
# 🔍 Processing 9924/10000: /content/extracted_OCR_Dataset/Date-Synth/images/08223.jpg
# 📄 Extracted Text:
# 29 NOV 2018
# 🔍 Processing 9925/10000: /content/extracted_OCR_Dataset/Date-Synth/images/48630.jpg
# 📄 Extracted Text:
# 0RP2219
# 🔍 Processing 9926/10000: /content/extracted_OCR_Dataset/Date-Synth/images/109038.jpg
# 📄 Extracted Text:
# JUL/13/2015
# 🔍 Processing 9927/10000: /content/extracted_OCR_Dataset/Date-Synth/images/44593.jpg
# 📄 Extracted Text:
# MAR/15/23
# 🔍 Processing 9928/10000: /content/extracted_OCR_Dataset/Date-Synth/images/08997.jpg
# 📄 Extracted Text:
# 11.MAR.2025
# 🔍 Processing 9929/10000: /content/extracted_OCR_Dataset/Date-Synth/images/113192.jpg
# 📄 Extracted Text:
# :19-MAR-22
# 🔍 Processing 9930/10000: /content/extracted_OCR_Dataset/Date-Synth/images/63833.jpg
# 📄 Extracted Text:
# 2021/07/15
# 🔍 Processing 9931/10000: /content/extracted_OCR_Dataset/Date-Synth/images/40866.jpg
# 📄 Extracted Text:
# ITEMPS-IT
# 🔍 Processing 9932/10000: /content/extracted_OCR_Dataset/Date-Synth/images/93838.jpg
# 📄 Extracted Text:
# ST REG
# 🔍 Processing 9933/10000: /content/extracted_OCR_Dataset/Date-Synth/images/82245.jpg
# 📄 Extracted Text:
# :2026/JUN/22
# 🔍 Processing 9934/10000: /content/extracted_OCR_Dataset/Date-Synth/images/64532.jpg
# 📄 Extracted Text:
# 18.07.2028
# 🔍 Processing 9935/10000: /content/extracted_OCR_Dataset/Date-Synth/images/98236.jpg
# 📄 Extracted Text:
# 2025.04
# 🔍 Processing 9936/10000: /content/extracted_OCR_Dataset/Date-Synth/images/66459.jpg
# 📄 Extracted Text:
# 16:03:20:00
# 🔍 Processing 9937/10000: /content/extracted_OCR_Dataset/Date-Synth/images/49149.jpg
# 📄 Extracted Text:
# 050CT24
# 🔍 Processing 9938/10000: /content/extracted_OCR_Dataset/Date-Synth/images/54171.jpg
# 📄 Extracted Text:
# 12.00
# 🔍 Processing 9939/10000: /content/extracted_OCR_Dataset/Date-Synth/images/108957.jpg
# 📄 Extracted Text:
# G SEP/28/2022
# 🔍 Processing 9940/10000: /content/extracted_OCR_Dataset/Date-Synth/images/47557.jpg
# 📄 Extracted Text:
# :
# 🔍 Processing 9941/10000: /content/extracted_OCR_Dataset/Date-Synth/images/11189.jpg
# 📄 Extracted Text:
# 12/2020
# 🔍 Processing 9942/10000: /content/extracted_OCR_Dataset/Date-Synth/images/37410.jpg
# 📄 Extracted Text:
# 2.0065-102
# 🔍 Processing 9943/10000: /content/extracted_OCR_Dataset/Date-Synth/images/74792.jpg
# 📄 Extracted Text:
# TAX($)
# 🔍 Processing 9944/10000: /content/extracted_OCR_Dataset/Date-Synth/images/112011.jpg
# 📄 Extracted Text:
# JUL/2016 E
# 🔍 Processing 9945/10000: /content/extracted_OCR_Dataset/Date-Synth/images/21294.jpg
# 📄 Extracted Text:
# JUL.03.17
# 🔍 Processing 9946/10000: /content/extracted_OCR_Dataset/Date-Synth/images/95777.jpg
# 📄 Extracted Text:
# JUL-20-2028
# 🔍 Processing 9947/10000: /content/extracted_OCR_Dataset/Date-Synth/images/60109.jpg
# 📄 Extracted Text:
# 2014 MAY 28
# 🔍 Processing 9948/10000: /content/extracted_OCR_Dataset/Date-Synth/images/53729.jpg
# 📄 Extracted Text:
# 05FEB2018
# 🔍 Processing 9949/10000: /content/extracted_OCR_Dataset/Date-Synth/images/03081.jpg
# 📄 Extracted Text:
# 2018-02:29
# 🔍 Processing 9950/10000: /content/extracted_OCR_Dataset/Date-Synth/images/121905.jpg
# 📄 Extracted Text:
# 09/10/19:
# 🔍 Processing 9951/10000: /content/extracted_OCR_Dataset/Date-Synth/images/65037.jpg
# 📄 Extracted Text:
# :2208/207
# 🔍 Processing 9952/10000: /content/extracted_OCR_Dataset/Date-Synth/images/82634.jpg
# 📄 Extracted Text:
# : 2018 FEB 27
# 🔍 Processing 9953/10000: /content/extracted_OCR_Dataset/Date-Synth/images/03032.jpg
# 📄 Extracted Text:
# 2028/09/26
# 🔍 Processing 9954/10000: /content/extracted_OCR_Dataset/Date-Synth/images/103030.jpg
# 📄 Extracted Text:
# -10 :16
# 🔍 Processing 9955/10000: /content/extracted_OCR_Dataset/Date-Synth/images/78992.jpg
# 📄 Extracted Text:
# 2017/07/17
# 🔍 Processing 9956/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84118.jpg
# 📄 Extracted Text:
# : 09 MAY 2028
# 🔍 Processing 9957/10000: /content/extracted_OCR_Dataset/Date-Synth/images/03836.jpg
# 📄 Extracted Text:
# 2012/04/28
# 🔍 Processing 9958/10000: /content/extracted_OCR_Dataset/Date-Synth/images/110817.jpg
# 📄 Extracted Text:
# :03/2016
# 🔍 Processing 9959/10000: /content/extracted_OCR_Dataset/Date-Synth/images/04625.jpg
# 📄 Extracted Text:
# 2012.JAN.18
# 🔍 Processing 9960/10000: /content/extracted_OCR_Dataset/Date-Synth/images/117033.jpg
# 📄 Extracted Text:
# : 2025.MAY.05
# 🔍 Processing 9961/10000: /content/extracted_OCR_Dataset/Date-Synth/images/102364.jpg
# 📄 Extracted Text:
# MAY-31-23
# 🔍 Processing 9962/10000: /content/extracted_OCR_Dataset/Date-Synth/images/27989.jpg
# 📄 Extracted Text:
# 2019.00
# 🔍 Processing 9963/10000: /content/extracted_OCR_Dataset/Date-Synth/images/80145.jpg
# 📄 Extracted Text:
# 29 05:2027
# 🔍 Processing 9964/10000: /content/extracted_OCR_Dataset/Date-Synth/images/02784.jpg
# 📄 Extracted Text:
# 2018.10.22
# 🔍 Processing 9965/10000: /content/extracted_OCR_Dataset/Date-Synth/images/45282.jpg
# 📄 Extracted Text:
# JUL:12.18
# 🔍 Processing 9966/10000: /content/extracted_OCR_Dataset/Date-Synth/images/88163.jpg
# 📄 Extracted Text:
# 30/03/27
# 🔍 Processing 9967/10000: /content/extracted_OCR_Dataset/Date-Synth/images/51013.jpg
# 📄 Extracted Text:
# SUB-X
# 🔍 Processing 9968/10000: /content/extracted_OCR_Dataset/Date-Synth/images/83492.jpg
# 📄 Extracted Text:
# : SEP/21/2015
# 🔍 Processing 9969/10000: /content/extracted_OCR_Dataset/Date-Synth/images/31541.jpg
# 📄 Extracted Text:
# 999 08.800
# 🔍 Processing 9970/10000: /content/extracted_OCR_Dataset/Date-Synth/images/00062.jpg
# 📄 Extracted Text:
# 26.01-2014
# 🔍 Processing 9971/10000: /content/extracted_OCR_Dataset/Date-Synth/images/112072.jpg
# 📄 Extracted Text:
# JUN / 2 0 2 6 D
# 🔍 Processing 9972/10000: /content/extracted_OCR_Dataset/Date-Synth/images/83822.jpg
# 📄 Extracted Text:
# AUG-08-2014
# 🔍 Processing 9973/10000: /content/extracted_OCR_Dataset/Date-Synth/images/120459.jpg
# 📄 Extracted Text:
# 2016/04E
# 🔍 Processing 9974/10000: /content/extracted_OCR_Dataset/Date-Synth/images/124003.jpg
# 📄 Extracted Text:
# 08.21@
# 🔍 Processing 9975/10000: /content/extracted_OCR_Dataset/Date-Synth/images/98355.jpg
# 📄 Extracted Text:
# 202.00
# 🔍 Processing 9976/10000: /content/extracted_OCR_Dataset/Date-Synth/images/84029.jpg
# 📄 Extracted Text:
# 0.7 / S/E-P / 2 0 2:7
# 🔍 Processing 9977/10000: /content/extracted_OCR_Dataset/Date-Synth/images/106393.jpg
# 📄 Extracted Text:
# A 09-24
# 🔍 Processing 9978/10000: /content/extracted_OCR_Dataset/Date-Synth/images/21098.jpg
# 📄 Extracted Text:
# AUG 06 15
# 🔍 Processing 9979/10000: /content/extracted_OCR_Dataset/Date-Synth/images/14083.jpg
# 📄 Extracted Text:
# NOV / 2 0 2 9
# 🔍 Processing 9980/10000: /content/extracted_OCR_Dataset/Date-Synth/images/90834.jpg
# 📄 Extracted Text:
# FEB/28/28
# 🔍 Processing 9981/10000: /content/extracted_OCR_Dataset/Date-Synth/images/32664.jpg
# 📄 Extracted Text:
# 23/JAN/2024
# 🔍 Processing 9982/10000: /content/extracted_OCR_Dataset/Date-Synth/images/70391.jpg
# 📄 Extracted Text:
# 2023/11/12
# 🔍 Processing 9983/10000: /content/extracted_OCR_Dataset/Date-Synth/images/88397.jpg
# 📄 Extracted Text:
# X26/06/26
# 🔍 Processing 9984/10000: /content/extracted_OCR_Dataset/Date-Synth/images/119538.jpg
# 📄 Extracted Text:
# GST REGUTIVE
# 🔍 Processing 9985/10000: /content/extracted_OCR_Dataset/Date-Synth/images/97907.jpg
# 📄 Extracted Text:
# 02-2018
# 🔍 Processing 9986/10000: /content/extracted_OCR_Dataset/Date-Synth/images/10545.jpg
# 📄 Extracted Text:
# 08-2027
# 🔍 Processing 9987/10000: /content/extracted_OCR_Dataset/Date-Synth/images/74566.jpg
# 📄 Extracted Text:
# IGU08417
# 🔍 Processing 9988/10000: /content/extracted_OCR_Dataset/Date-Synth/images/120745.jpg
# 📄 Extracted Text:
# RM
# 🔍 Processing 9989/10000: /content/extracted_OCR_Dataset/Date-Synth/images/118080.jpg
# 📄 Extracted Text:
# ***
# 🔍 Processing 9990/10000: /content/extracted_OCR_Dataset/Date-Synth/images/18942.jpg
# 📄 Extracted Text:
# 13,JAN.21
# 🔍 Processing 9991/10000: /content/extracted_OCR_Dataset/Date-Synth/images/109572.jpg
# 📄 Extracted Text:
# 0.6"A P/R/2 0/N8B
# 🔍 Processing 9992/10000: /content/extracted_OCR_Dataset/Date-Synth/images/104288.jpg
# 📄 Extracted Text:
# (2023/JUL/28
# 🔍 Processing 9993/10000: /content/extracted_OCR_Dataset/Date-Synth/images/71490.jpg
# 📄 Extracted Text:
# 2029/04/12
# 🔍 Processing 9994/10000: /content/extracted_OCR_Dataset/Date-Synth/images/07729.jpg
# 📄 Extracted Text:
# JLAN 30.2018
# 🔍 Processing 9995/10000: /content/extracted_OCR_Dataset/Date-Synth/images/67785.jpg
# 📄 Extracted Text:
# 09012019
# 🔍 Processing 9996/10000: /content/extracted_OCR_Dataset/Date-Synth/images/125066.jpg
# 📄 Extracted Text:
# 2028-APR-04
# 🔍 Processing 9997/10000: /content/extracted_OCR_Dataset/Date-Synth/images/124939.jpg
# 📄 Extracted Text:
# 2-019-05-28
# 🔍 Processing 9998/10000: /content/extracted_OCR_Dataset/Date-Synth/images/104198.jpg
# 📄 Extracted Text:
# 2029/06/22
# 🔍 Processing 9999/10000: /content/extracted_OCR_Dataset/Date-Synth/images/126087.jpg
# 📄 Extracted Text:
# 0
# 🔍 Processing 10000/10000: /content/extracted_OCR_Dataset/Date-Synth/images/31764.jpg
# 📄 Extracted Text:
# TOTAL: 23:018
#  Finished processing 10000 images.

# %%
# !pip install python-Levenshtein

import Levenshtein

# ✅ Step 1: Load Ground Truth Data
# You should have a dictionary {image_path: actual_text} for comparison
ground_truth = {
    "/content/extracted_OCR_Dataset/image1.jpg": "This is the correct text",
    "/content/extracted_OCR_Dataset/image2.jpg": "Another example of OCR",
    # Add more image-to-text mappings
}

# ✅ Step 2: Define Accuracy Calculation Function
def calculate_accuracy(ocr_results, ground_truth):
    total_images = len(ground_truth)
    total_cer = 0  # Character Error Rate
    total_wer = 0  # Word Error Rate

    for img_path, actual_text in ground_truth.items():
        if img_path in ocr_results:
            predicted_text = ocr_results[img_path]

            # ✅ Compute Character Error Rate (CER)
            cer = Levenshtein.distance(actual_text, predicted_text) / max(1, len(actual_text))
            total_cer += cer

            # ✅ Compute Word Error Rate (WER)
            actual_words = actual_text.split()
            predicted_words = predicted_text.split()
            wer = Levenshtein.distance(" ".join(actual_words), " ".join(predicted_words)) / max(1, len(actual_words))
            total_wer += wer

    # ✅ Compute Final Accuracy Scores
    avg_cer = (1 - (total_cer / total_images)) * 100
    avg_wer = (1 - (total_wer / total_images)) * 100

    print(f"✅ OCR Accuracy Results:")
    print(f"🎯 Character-Level Accuracy: {avg_cer:.2f}%")
    print(f"🎯 Word-Level Accuracy: {avg_wer:.2f}%")

# ✅ Step 3: Run Accuracy Calculation
calculate_accuracy(ocr_results, ground_truth)
# Out:
# Collecting python-Levenshtein
#   Downloading python_levenshtein-0.27.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.27.1 (from python-Levenshtein)
#   Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.1->python-Levenshtein)
#   Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading python_levenshtein-0.27.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 3.3 MB/s eta 0:00:00
# Downloading rapidfuzz-3.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 41.4 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.27.1 python-Levenshtein-0.27.1 rapidfuzz-3.12.2
# ✅ OCR Accuracy Results:
# 🎯 Character-Level Accuracy: 100.00%
# 🎯 Word-Level Accuracy: 100.00%

# %%
# ✅ Step 10: Save OCR Results to a Text File
with open(output_text_file, "w") as f:
    for img, text in ocr_results.items():
        f.write(f"Image: {img}\nExtracted Text:\n{text}\n")
        f.write("="*50 + "\n")

print(f"✅ OCR results saved to: {output_text_file}")

# ✅ Step 11: Download OCR Results
from google.colab import files
files.download(output_text_file)
# Out:
# ✅ OCR results saved to: /content/ocr_results.txt

# %%
# ✅ Step 12: Save OCR Results to Google Drive
drive_save_path = "/content/drive/MyDrive/OCR_Results.txt"
shutil.move(output_text_file, drive_save_path)
print(f"✅ OCR results saved to Google Drive at: {drive_save_path}")
# Out:
# ✅ OCR results saved to Google Drive at: /content/drive/MyDrive/OCR_Results.txt

# %%
# ✅ Define save path
model_save_path = "/content/trained_trocr_model"

# ✅ Save the trained model and processor
model.save_pretrained(model_save_path)
processor.save_pretrained(model_save_path)

print(f"✅ Model saved at: {model_save_path}")
# Out:
# ✅ Model saved at: /content/trained_trocr_model

# %%
import shutil
from google.colab import files

# ✅ Compress the model folder into a ZIP file
shutil.make_archive("trocr_model", 'zip', model_save_path)

# ✅ Download the ZIP file
files.download("trocr_model.zip")

# %%
drive_save_path = "/content/drive/MyDrive/trained_trocr_model"

# ✅ Move model to Google Drive
shutil.move(model_save_path, drive_save_path)

print(f"✅ Model saved to Google Drive at: {drive_save_path}")
# Out:
# ✅ Model saved to Google Drive at: /content/drive/MyDrive/trained_trocr_model
